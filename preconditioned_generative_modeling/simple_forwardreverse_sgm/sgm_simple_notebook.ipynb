# %% [markdown]
# # Score-based Generative Modeling with SDEs (Simple examples)

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import torch.nn as nn
import lib.toy_data as toy_data
import numpy as np

# %% [markdown]
# Basic parameters

# %%
learning_rate = 1e-3 # learning rate for training neural network
batch_size = 256  # batch size during training of neural network
epochs = 100000   # Number of training epochs for the neural network
T = 5    # Forward simulation time in the forward SDE
dataset = 'moons' # Dataset choice, see toy_data for full options of toy datasets ('checkerboard','8gaussians','2spirals','swissroll','moons',etc.)

# %% [markdown]
# We first initialize the neural net that models the score function.

# %%
## Model construction

class DenoisingModel(nn.Module):
    
    def __init__(self, hidden_units=32):
        super(DenoisingModel, self).__init__()
        # hidden_units = 32
        
        # data and timestep
        self.fc1 = nn.Linear(3, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc1.weight)
        self.activation1 = nn.GELU()
        self.fc2 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc2.weight)
        self.activation2 = nn.GELU()
        self.fc3 = nn.Linear(int(hidden_units), 3, bias=True)
        nn.init.xavier_uniform_(self.fc3.weight)
        self.activation3 = nn.GELU()
        
        self.fc4 = nn.Linear(3, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc4.weight)
        self.activation4 = nn.GELU()
        self.fc5 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc5.weight)
        self.activation5 = nn.GELU()
        self.fc6 = nn.Linear(int(hidden_units), 3, bias=True)
        nn.init.xavier_uniform_(self.fc6.weight)
        self.activation6 = nn.GELU()
        
        self.fc7 = nn.Linear(3, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc7.weight)
        self.activation7 = nn.GELU()
        self.fc8 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc8.weight)
        self.activation8 = nn.GELU()
        self.fc9 = nn.Linear(int(hidden_units), 2, bias=True)
        nn.init.xavier_uniform_(self.fc9.weight)
        
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.activation1(x)
        x = self.fc2(x)
        x = self.activation2(x)
        x = self.fc3(x)
        x = self.activation3(x)
        x = self.fc4(x)
        x = self.activation4(x)
        x = self.fc5(x)
        x = self.activation5(x)
        x = self.fc6(x)
        x = self.activation6(x)
        x = self.fc7(x)
        x = self.activation7(x)
        x = self.fc8(x)
        x = self.activation8(x)
        x = self.fc9(x)
        
        return x
      
scorenet = DenoisingModel()
print(scorenet)
optimizer = optim.Adam(scorenet.parameters(), lr=learning_rate)
# Out:
# DenoisingModel(
#   (fc1): Linear(in_features=3, out_features=32, bias=True)
#   (activation1): GELU(approximate='none')
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (activation2): GELU(approximate='none')
#   (fc3): Linear(in_features=32, out_features=3, bias=True)
#   (activation3): GELU(approximate='none')
#   (fc4): Linear(in_features=3, out_features=32, bias=True)
#   (activation4): GELU(approximate='none')
#   (fc5): Linear(in_features=32, out_features=32, bias=True)
#   (activation5): GELU(approximate='none')
#   (fc6): Linear(in_features=32, out_features=3, bias=True)
#   (activation6): GELU(approximate='none')
#   (fc7): Linear(in_features=3, out_features=32, bias=True)
#   (activation7): GELU(approximate='none')
#   (fc8): Linear(in_features=32, out_features=32, bias=True)
#   (activation8): GELU(approximate='none')
#   (fc9): Linear(in_features=32, out_features=2, bias=True)
# )

# %% [markdown]
# Define loss functions. These loss functions assume that the forward process is a standard OU process dx = -x/2 dt + dW. The choice of \lambda(t) in the SGM objective function is equal to 1 (the constant in front of the dW term).

# %%
# Loss function -- we use the denoising diffusions objective function
# Scorenet is the score model, samples are the training samples, Tmin/Tmax are the time interval that is being trained on, and eps is so that Tmin is not sampled. 

def time_dsm_score_estimator(scorenet,samples,Tmin,Tmax,eps):

    t = torch.rand(samples.shape[0]) * (Tmax - Tmin - eps) + eps + Tmin # sample uniformly from time interval

    # Add noise to the training samples
    sigmas = torch.sqrt(1 - torch.exp(-t))
    sigmas = sigmas.view(samples.shape[0],*([1]*len(samples.shape[1:])))
    noise = torch.randn_like(samples) * sigmas
    tenlarge = t.repeat(2,1).T
    perturbed_samples = samples * torch.exp(-0.5 * tenlarge) + noise

    # Evaluate score and marginal score on the perturbed samples
    target = - 1/ (sigmas ** 2) * (noise)
    score_eval_samples = torch.cat((t.reshape(-1,1),perturbed_samples),1)
    scores = scorenet(score_eval_samples)

    # Evaluate the loss function 
    target = target.view(target.shape[0],-1)
    scores = scores.view(scores.shape[0],-1)
    loss = 0.5 * ((scores-target) ** 2).sum(dim = -1) 

    return loss.mean(dim = 0)


# Loss function
# This is for if you have a specific mesh for the time interval you would like the network to train on. 
def deterministic_time_dsm_score_estimator(scorenet,samples,t):

    loss = 0
    for ii in range(len(t)-1):

        # Add noise to the training samples
        sigmas = torch.sqrt(1 - torch.exp(-t[ii]))
        noise = torch.randn_like(samples) * sigmas
        perturbed_samples = samples * torch.exp(-0.5 * t[ii]) + noise

        # Evaluate score and marginal score on perturbed samples
        target = - 1/ (sigmas ** 2) * (noise)
        score_eval_samples = torch.cat((t[ii].repeat(perturbed_samples.shape[0],1),perturbed_samples),1)
        scores = scorenet(score_eval_samples)

        # Evaluate loss function at this particular t[ii]
        target = target.view(target.shape[0],-1)
        scores = scores.view(scores.shape[0],-1)
        loss_vec = 0.5 * ((scores-target) ** 2).sum(dim = -1) 
        loss = loss + (t[ii+1]-t[ii])*loss_vec.mean(dim = 0)

    return loss

# %% [markdown]
# Training the score network

# %%
# Training the score network

for step in range(epochs):
    # sample toy_data
    p_samples = toy_data.inf_train_gen(dataset, batch_size)
    samples = torch.tensor(p_samples).to(dtype = torch.float32)

    # evaluate loss function and gradient
    loss = time_dsm_score_estimator(scorenet,samples,0,T,eps = 0.0005)
    optimizer.zero_grad()
    loss.backward()

    # Update score network
    optimizer.step()

    if not step%100:
        print(loss,step)
# Out:
# tensor(1.7214, grad_fn=<MeanBackward1>) 0
# tensor(2.8794, grad_fn=<MeanBackward1>) 100
# tensor(1.6354, grad_fn=<MeanBackward1>) 200
# tensor(0.9316, grad_fn=<MeanBackward1>) 300
# tensor(1.1675, grad_fn=<MeanBackward1>) 400
# tensor(2.3348, grad_fn=<MeanBackward1>) 500
# tensor(1.6875, grad_fn=<MeanBackward1>) 600
# tensor(1.2648, grad_fn=<MeanBackward1>) 700
# tensor(1.9373, grad_fn=<MeanBackward1>) 800
# tensor(5.7225, grad_fn=<MeanBackward1>) 900
# tensor(1.9955, grad_fn=<MeanBackward1>) 1000
# tensor(1.2396, grad_fn=<MeanBackward1>) 1100
# tensor(1.1669, grad_fn=<MeanBackward1>) 1200
# tensor(1.1330, grad_fn=<MeanBackward1>) 1300
# tensor(1.1946, grad_fn=<MeanBackward1>) 1400
# tensor(0.8674, grad_fn=<MeanBackward1>) 1500
# tensor(1.8069, grad_fn=<MeanBackward1>) 1600
# tensor(4.8629, grad_fn=<MeanBackward1>) 1700
# tensor(3.7639, grad_fn=<MeanBackward1>) 1800
# tensor(1.2118, grad_fn=<MeanBackward1>) 1900
# tensor(1.2192, grad_fn=<MeanBackward1>) 2000
# tensor(2.8178, grad_fn=<MeanBackward1>) 2100
# tensor(0.8854, grad_fn=<MeanBackward1>) 2200
# tensor(6.9422, grad_fn=<MeanBackward1>) 2300
# tensor(1.7741, grad_fn=<MeanBackward1>) 2400
# tensor(1.1547, grad_fn=<MeanBackward1>) 2500
# tensor(1.0304, grad_fn=<MeanBackward1>) 2600
# tensor(1.1016, grad_fn=<MeanBackward1>) 2700
# tensor(0.9592, grad_fn=<MeanBackward1>) 2800
# tensor(1.0602, grad_fn=<MeanBackward1>) 2900
# tensor(1.0797, grad_fn=<MeanBackward1>) 3000
# tensor(2.5110, grad_fn=<MeanBackward1>) 3100
# tensor(1.2617, grad_fn=<MeanBackward1>) 3200
# tensor(1.2691, grad_fn=<MeanBackward1>) 3300
# tensor(1.1776, grad_fn=<MeanBackward1>) 3400
# tensor(2.2288, grad_fn=<MeanBackward1>) 3500
# tensor(6.5532, grad_fn=<MeanBackward1>) 3600
# tensor(1.1999, grad_fn=<MeanBackward1>) 3700
# tensor(1.4719, grad_fn=<MeanBackward1>) 3800
# tensor(5.3035, grad_fn=<MeanBackward1>) 3900
# tensor(1.0800, grad_fn=<MeanBackward1>) 4000
# tensor(1.0469, grad_fn=<MeanBackward1>) 4100
# tensor(0.8327, grad_fn=<MeanBackward1>) 4200
# tensor(0.9504, grad_fn=<MeanBackward1>) 4300
# tensor(1.0654, grad_fn=<MeanBackward1>) 4400
# tensor(1.4019, grad_fn=<MeanBackward1>) 4500
# tensor(1.1946, grad_fn=<MeanBackward1>) 4600
# tensor(5.5036, grad_fn=<MeanBackward1>) 4700
# tensor(0.8499, grad_fn=<MeanBackward1>) 4800
# tensor(3.1586, grad_fn=<MeanBackward1>) 4900
# tensor(0.8838, grad_fn=<MeanBackward1>) 5000
# tensor(1.6324, grad_fn=<MeanBackward1>) 5100
# tensor(1.0883, grad_fn=<MeanBackward1>) 5200
# tensor(1.1965, grad_fn=<MeanBackward1>) 5300
# tensor(1.2875, grad_fn=<MeanBackward1>) 5400
# tensor(0.8043, grad_fn=<MeanBackward1>) 5500
# tensor(0.8764, grad_fn=<MeanBackward1>) 5600
# tensor(2.3272, grad_fn=<MeanBackward1>) 5700
# tensor(1.2624, grad_fn=<MeanBackward1>) 5800
# tensor(1.6194, grad_fn=<MeanBackward1>) 5900
# tensor(4.7300, grad_fn=<MeanBackward1>) 6000
# tensor(0.7550, grad_fn=<MeanBackward1>) 6100
# tensor(1.1028, grad_fn=<MeanBackward1>) 6200
# tensor(1.8343, grad_fn=<MeanBackward1>) 6300
# tensor(2.8916, grad_fn=<MeanBackward1>) 6400
# tensor(0.9382, grad_fn=<MeanBackward1>) 63000
# tensor(2.3639, grad_fn=<MeanBackward1>) 63100
# tensor(2.3267, grad_fn=<MeanBackward1>) 63200
# tensor(0.6763, grad_fn=<MeanBackward1>) 63300
# tensor(1.6984, grad_fn=<MeanBackward1>) 63400
# tensor(1.0021, grad_fn=<MeanBackward1>) 63500
# tensor(0.9650, grad_fn=<MeanBackward1>) 63600
# tensor(1.5229, grad_fn=<MeanBackward1>) 63700
# tensor(1.4212, grad_fn=<MeanBackward1>) 63800
# tensor(1.1033, grad_fn=<MeanBackward1>) 63900
# tensor(2.9506, grad_fn=<MeanBackward1>) 64000
# tensor(4.4204, grad_fn=<MeanBackward1>) 64100
# tensor(1.0242, grad_fn=<MeanBackward1>) 64200
# tensor(0.7650, grad_fn=<MeanBackward1>) 64300
# tensor(0.6980, grad_fn=<MeanBackward1>) 64400
# tensor(0.8386, grad_fn=<MeanBackward1>) 64500
# tensor(1.4852, grad_fn=<MeanBackward1>) 64600
# tensor(0.9203, grad_fn=<MeanBackward1>) 64700
# tensor(0.6766, grad_fn=<MeanBackward1>) 64800
# tensor(0.8676, grad_fn=<MeanBackward1>) 64900
# tensor(1.9328, grad_fn=<MeanBackward1>) 65000
# tensor(1.3354, grad_fn=<MeanBackward1>) 65100
# tensor(0.7957, grad_fn=<MeanBackward1>) 65200
# tensor(1.9171, grad_fn=<MeanBackward1>) 65300
# tensor(1.9403, grad_fn=<MeanBackward1>) 65400
# tensor(1.4000, grad_fn=<MeanBackward1>) 65500
# tensor(0.8220, grad_fn=<MeanBackward1>) 65600
# tensor(0.8190, grad_fn=<MeanBackward1>) 65700
# tensor(0.9467, grad_fn=<MeanBackward1>) 65800
# tensor(1.7607, grad_fn=<MeanBackward1>) 65900
# tensor(11.5807, grad_fn=<MeanBackward1>) 66000
# tensor(1.1036, grad_fn=<MeanBackward1>) 66100
# tensor(1.1800, grad_fn=<MeanBackward1>) 66200
# tensor(0.6745, grad_fn=<MeanBackward1>) 66300
# tensor(1.1045, grad_fn=<MeanBackward1>) 66400
# tensor(1.0334, grad_fn=<MeanBackward1>) 66500
# tensor(0.8298, grad_fn=<MeanBackward1>) 66600
# tensor(0.9442, grad_fn=<MeanBackward1>) 66700
# tensor(1.9198, grad_fn=<MeanBackward1>) 66800
# tensor(0.9175, grad_fn=<MeanBackward1>) 66900
# tensor(0.8471, grad_fn=<MeanBackward1>) 67000
# tensor(1.0992, grad_fn=<MeanBackward1>) 67100
# tensor(4.7100, grad_fn=<MeanBackward1>) 67200
# tensor(1.5070, grad_fn=<MeanBackward1>) 67300
# tensor(0.8608, grad_fn=<MeanBackward1>) 67400
# tensor(1.8901, grad_fn=<MeanBackward1>) 67500
# tensor(1.8940, grad_fn=<MeanBackward1>) 67600
# tensor(2.5273, grad_fn=<MeanBackward1>) 67700
# tensor(2.3157, grad_fn=<MeanBackward1>) 67800
# tensor(2.1337, grad_fn=<MeanBackward1>) 67900
# tensor(0.8342, grad_fn=<MeanBackward1>) 68000
# tensor(3.4959, grad_fn=<MeanBackward1>) 68100
# tensor(2.9711, grad_fn=<MeanBackward1>) 83600
# tensor(2.2057, grad_fn=<MeanBackward1>) 83700
# tensor(1.2232, grad_fn=<MeanBackward1>) 83800
# tensor(4.0230, grad_fn=<MeanBackward1>) 83900
# tensor(1.0378, grad_fn=<MeanBackward1>) 84000
# tensor(3.2502, grad_fn=<MeanBackward1>) 84100
# tensor(1.2375, grad_fn=<MeanBackward1>) 84200
# tensor(1.0101, grad_fn=<MeanBackward1>) 84300
# tensor(1.9930, grad_fn=<MeanBackward1>) 84400
# tensor(0.9828, grad_fn=<MeanBackward1>) 84500
# tensor(1.3802, grad_fn=<MeanBackward1>) 84600
# tensor(2.5235, grad_fn=<MeanBackward1>) 84700
# tensor(1.1352, grad_fn=<MeanBackward1>) 84800
# tensor(2.2298, grad_fn=<MeanBackward1>) 84900
# tensor(1.3224, grad_fn=<MeanBackward1>) 85000
# tensor(0.8458, grad_fn=<MeanBackward1>) 85100
# tensor(1.0503, grad_fn=<MeanBackward1>) 85200
# tensor(0.7884, grad_fn=<MeanBackward1>) 85300
# tensor(0.8537, grad_fn=<MeanBackward1>) 85400
# tensor(1.1704, grad_fn=<MeanBackward1>) 85500
# tensor(0.8479, grad_fn=<MeanBackward1>) 85600
# tensor(1.1908, grad_fn=<MeanBackward1>) 85700
# tensor(0.9055, grad_fn=<MeanBackward1>) 85800
# tensor(0.8823, grad_fn=<MeanBackward1>) 85900
# tensor(2.0371, grad_fn=<MeanBackward1>) 86000
# tensor(0.9130, grad_fn=<MeanBackward1>) 86100
# tensor(2.2963, grad_fn=<MeanBackward1>) 86200
# tensor(0.7847, grad_fn=<MeanBackward1>) 86300
# tensor(3.5226, grad_fn=<MeanBackward1>) 86400
# tensor(0.8138, grad_fn=<MeanBackward1>) 86500
# tensor(0.6488, grad_fn=<MeanBackward1>) 86600
# tensor(1.2057, grad_fn=<MeanBackward1>) 86700
# tensor(0.8520, grad_fn=<MeanBackward1>) 86800
# tensor(0.8109, grad_fn=<MeanBackward1>) 86900
# tensor(2.3728, grad_fn=<MeanBackward1>) 87000
# tensor(1.1127, grad_fn=<MeanBackward1>) 87100
# tensor(1.1813, grad_fn=<MeanBackward1>) 87200
# tensor(1.5357, grad_fn=<MeanBackward1>) 87300
# tensor(0.7454, grad_fn=<MeanBackward1>) 87400
# tensor(5.2202, grad_fn=<MeanBackward1>) 87500
# tensor(1.0630, grad_fn=<MeanBackward1>) 87600
# tensor(0.6474, grad_fn=<MeanBackward1>) 87700
# tensor(7.1338, grad_fn=<MeanBackward1>) 87800
# tensor(1.0475, grad_fn=<MeanBackward1>) 87900
# tensor(1.8445, grad_fn=<MeanBackward1>) 88000
# tensor(0.7725, grad_fn=<MeanBackward1>) 88100
# tensor(1.0465, grad_fn=<MeanBackward1>) 88200
# tensor(3.4734, grad_fn=<MeanBackward1>) 88300
# tensor(1.0482, grad_fn=<MeanBackward1>) 88400
# tensor(1.0037, grad_fn=<MeanBackward1>) 88500
# tensor(1.0363, grad_fn=<MeanBackward1>) 88600
# tensor(1.0741, grad_fn=<MeanBackward1>) 99000
# tensor(1.3824, grad_fn=<MeanBackward1>) 99100
# tensor(0.7769, grad_fn=<MeanBackward1>) 99200
# tensor(2.2394, grad_fn=<MeanBackward1>) 99300
# tensor(1.2655, grad_fn=<MeanBackward1>) 99400
# tensor(0.8161, grad_fn=<MeanBackward1>) 99500
# tensor(0.6287, grad_fn=<MeanBackward1>) 99600
# tensor(0.7336, grad_fn=<MeanBackward1>) 99700
# tensor(1.2099, grad_fn=<MeanBackward1>) 99800
# tensor(1.6125, grad_fn=<MeanBackward1>) 99900

# %% [markdown]
# SDE simulation functions

# %%
# This is the solving the OU process exactly given deterministic initial conditions
def ou_dynamics(init, T):
    init = init * torch.exp(- 0.5 * T) + torch.sqrt(1-torch.exp(-T)) * torch.randn_like(init)
    return init

def reverse_sde(score, init,T,lr=0.01):
    step = int(T/lr) 
    for i in range(step,-1,-1):
        current_lr = lr
        evalpoint = torch.cat(((torch.tensor(lr*i)).repeat(init.shape[0],1),init),1)
        init = init + current_lr  * (init/2 + score(evalpoint).detach() )
        init = init + torch.randn_like(init) * np.sqrt(current_lr)
    return init


# The following is the deterministic ODE flow that can also sample from the target distribution

def reverse_ode_flow(score,init,T,lr = 0.01):
    step = int(T/lr)
    for i in range(step,-1,-1):
        current_lr = lr
        evalpoint = torch.cat(((torch.tensor(lr*i)).repeat(init.shape[0],1),init),1)
        init = init + current_lr  * (init/2 + 1/2 * score(evalpoint).detach() )
    return init

# %% [markdown]
# Sample using the score network

# %%
# Denoising the normal distribution 
samples_lang = torch.randn(10000, 2) # * (right_bound - left_bound) + left_bound
samples_lang = reverse_sde(scorenet, samples_lang,torch.tensor(T)).detach().numpy()


# Denoising samples from the training data
samples = torch.tensor(toy_data.inf_train_gen('moons', batch_size = 10000))
samples_lang_noisedtraining = samples * torch.exp(-0.5 * torch.tensor(T)) + torch.sqrt(1-torch.exp(-torch.tensor(T))) * torch.randn_like(samples)
samples_lang_noisedtraining =reverse_sde(scorenet, samples_lang_noisedtraining.to(dtype=torch.float32),torch.tensor(T)).detach().numpy()

# Deterministically evolving the normal distribution 
samples_lang_deterministic = torch.randn(10000,2)
samples_lang_deterministic = reverse_ode_flow(scorenet,samples_lang_deterministic,torch.tensor(T)).detach().numpy()

# %%
plt.clf()
p_samples = toy_data.inf_train_gen(dataset, batch_size = 10000)
samples_true = torch.tensor(p_samples).to(dtype = torch.float32)
plt.scatter(samples_true[:,0],samples_true[:,1],s = 0.1)
plt.axis('square')
plt.title('True samples')
plt.show()


plt.clf()
plt.scatter(samples_lang[:,0],samples_lang[:,1],s = 0.1)
plt.axis('square')
plt.title('Denoising normal distribution')
plt.show()


plt.clf()
plt.scatter(samples_lang_noisedtraining[:,0],samples_lang_noisedtraining[:,1],s = 0.1)
plt.axis('square')
plt.title('Denoising noised training samples')
plt.show()


plt.clf()
plt.scatter(samples_lang_deterministic[:,0],samples_lang_deterministic[:,1],s = 0.1)
plt.axis('square')
plt.title('Denoising normal with ODE flow')
plt.show()
