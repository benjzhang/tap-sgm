# %% [markdown]
# # Score-based Generative Modeling with SDEs (Simple examples)

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import torch.nn as nn
import lib.toy_data as toy_data
import numpy as np

# %% [markdown]
# Basic parameters

# %%
learning_rate = 1e-3 # learning rate for training neural network
batch_size = 256  # batch size during training of neural network
epochs = 100000   # Number of training epochs for the neural network
T = 5    # Forward simulation time in the forward SDE
dataset = 'moons' # Dataset choice, see toy_data for full options of toy datasets ('checkerboard','8gaussians','2spirals','swissroll','moons',etc.)

# %% [markdown]
# We first initialize the neural net that models the score function.

# %%
## Model construction

class DenoisingModel(nn.Module):
    
    def __init__(self, hidden_units=32):
        super(DenoisingModel, self).__init__()
        # hidden_units = 32
        
        # data and timestep
        self.fc1 = nn.Linear(3, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc1.weight)
        self.activation1 = nn.GELU()
        self.fc2 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc2.weight)
        self.activation2 = nn.GELU()
        self.fc3 = nn.Linear(int(hidden_units), 3, bias=True)
        nn.init.xavier_uniform_(self.fc3.weight)
        self.activation3 = nn.GELU()
        
        self.fc4 = nn.Linear(3, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc4.weight)
        self.activation4 = nn.GELU()
        self.fc5 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc5.weight)
        self.activation5 = nn.GELU()
        self.fc6 = nn.Linear(int(hidden_units), 3, bias=True)
        nn.init.xavier_uniform_(self.fc6.weight)
        self.activation6 = nn.GELU()
        
        self.fc7 = nn.Linear(3, int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc7.weight)
        self.activation7 = nn.GELU()
        self.fc8 = nn.Linear(int(hidden_units), int(hidden_units), bias=True)
        nn.init.xavier_uniform_(self.fc8.weight)
        self.activation8 = nn.GELU()
        self.fc9 = nn.Linear(int(hidden_units), 2, bias=True)
        nn.init.xavier_uniform_(self.fc9.weight)
        
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.activation1(x)
        x = self.fc2(x)
        x = self.activation2(x)
        x = self.fc3(x)
        x = self.activation3(x)
        x = self.fc4(x)
        x = self.activation4(x)
        x = self.fc5(x)
        x = self.activation5(x)
        x = self.fc6(x)
        x = self.activation6(x)
        x = self.fc7(x)
        x = self.activation7(x)
        x = self.fc8(x)
        x = self.activation8(x)
        x = self.fc9(x)
        
        return x
      
scorenet = DenoisingModel()
print(scorenet)
optimizer = optim.Adam(scorenet.parameters(), lr=learning_rate)
# Out:
# DenoisingModel(
#   (fc1): Linear(in_features=3, out_features=32, bias=True)
#   (activation1): GELU(approximate='none')
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (activation2): GELU(approximate='none')
#   (fc3): Linear(in_features=32, out_features=3, bias=True)
#   (activation3): GELU(approximate='none')
#   (fc4): Linear(in_features=3, out_features=32, bias=True)
#   (activation4): GELU(approximate='none')
#   (fc5): Linear(in_features=32, out_features=32, bias=True)
#   (activation5): GELU(approximate='none')
#   (fc6): Linear(in_features=32, out_features=3, bias=True)
#   (activation6): GELU(approximate='none')
#   (fc7): Linear(in_features=3, out_features=32, bias=True)
#   (activation7): GELU(approximate='none')
#   (fc8): Linear(in_features=32, out_features=32, bias=True)
#   (activation8): GELU(approximate='none')
#   (fc9): Linear(in_features=32, out_features=2, bias=True)
# )

# %% [markdown]
# Define loss functions. These loss functions assume that the forward process is a standard OU process dx = -x/2 dt + dW. The choice of \lambda(t) in the SGM objective function is equal to 1 (the constant in front of the dW term).

# %%
# Loss function -- we use the denoising diffusions objective function
# Scorenet is the score model, samples are the training samples, Tmin/Tmax are the time interval that is being trained on, and eps is so that Tmin is not sampled. 

def time_dsm_score_estimator(scorenet,samples,Tmin,Tmax,eps):

    t = torch.rand(samples.shape[0]) * (Tmax - Tmin - eps) + eps + Tmin # sample uniformly from time interval

    # Add noise to the training samples
    sigmas = torch.sqrt(1 - torch.exp(-t))
    sigmas = sigmas.view(samples.shape[0],*([1]*len(samples.shape[1:])))
    noise = torch.randn_like(samples) * sigmas
    tenlarge = t.repeat(2,1).T
    perturbed_samples = samples * torch.exp(-0.5 * tenlarge) + noise

    # Evaluate score and marginal score on the perturbed samples
    target = - 1/ (sigmas ** 2) * (noise)
    score_eval_samples = torch.cat((t.reshape(-1,1),perturbed_samples),1)
    scores = scorenet(score_eval_samples)

    # Evaluate the loss function 
    target = target.view(target.shape[0],-1)
    scores = scores.view(scores.shape[0],-1)
    loss = 0.5 * ((scores-target) ** 2).sum(dim = -1) 

    return loss.mean(dim = 0)


# Loss function
# This is for if you have a specific mesh for the time interval you would like the network to train on. 
def deterministic_time_dsm_score_estimator(scorenet,samples,t):

    loss = 0
    for ii in range(len(t)-1):

        # Add noise to the training samples
        sigmas = torch.sqrt(1 - torch.exp(-t[ii]))
        noise = torch.randn_like(samples) * sigmas
        perturbed_samples = samples * torch.exp(-0.5 * t[ii]) + noise

        # Evaluate score and marginal score on perturbed samples
        target = - 1/ (sigmas ** 2) * (noise)
        score_eval_samples = torch.cat((t[ii].repeat(perturbed_samples.shape[0],1),perturbed_samples),1)
        scores = scorenet(score_eval_samples)

        # Evaluate loss function at this particular t[ii]
        target = target.view(target.shape[0],-1)
        scores = scores.view(scores.shape[0],-1)
        loss_vec = 0.5 * ((scores-target) ** 2).sum(dim = -1) 
        loss = loss + (t[ii+1]-t[ii])*loss_vec.mean(dim = 0)

    return loss

# %% [markdown]
# Training the score network

# %%
# Training the score network

for step in range(epochs):
    # sample toy_data
    p_samples = toy_data.inf_train_gen(dataset, batch_size)
    samples = torch.tensor(p_samples).to(dtype = torch.float32)

    # evaluate loss function and gradient
    loss = time_dsm_score_estimator(scorenet,samples,0,T,eps = 0.0001)
    optimizer.zero_grad()
    loss.backward()

    # Update score network
    optimizer.step()

    if not step%100:
        print(loss,step)
# Out:
# tensor(1.6600, grad_fn=<MeanBackward1>) 0
# tensor(1.7359, grad_fn=<MeanBackward1>) 100
# tensor(1.2994, grad_fn=<MeanBackward1>) 200
# tensor(0.9481, grad_fn=<MeanBackward1>) 300
# tensor(0.9368, grad_fn=<MeanBackward1>) 400
# tensor(0.9310, grad_fn=<MeanBackward1>) 500
# tensor(0.5081, grad_fn=<MeanBackward1>) 600
# tensor(0.9030, grad_fn=<MeanBackward1>) 700
# tensor(1.4139, grad_fn=<MeanBackward1>) 800
# tensor(0.8136, grad_fn=<MeanBackward1>) 900
# tensor(1.0074, grad_fn=<MeanBackward1>) 1000
# tensor(6.7275, grad_fn=<MeanBackward1>) 1100
# tensor(0.5036, grad_fn=<MeanBackward1>) 1200
# tensor(2.1299, grad_fn=<MeanBackward1>) 1300
# tensor(15.9936, grad_fn=<MeanBackward1>) 1400
# tensor(3.9594, grad_fn=<MeanBackward1>) 1500
# tensor(1.0345, grad_fn=<MeanBackward1>) 1600
# tensor(2.3584, grad_fn=<MeanBackward1>) 1700
# tensor(0.9626, grad_fn=<MeanBackward1>) 1800
# tensor(1.9552, grad_fn=<MeanBackward1>) 1900
# tensor(1.0330, grad_fn=<MeanBackward1>) 2000
# tensor(0.8057, grad_fn=<MeanBackward1>) 2100
# tensor(0.6663, grad_fn=<MeanBackward1>) 2200
# tensor(0.9466, grad_fn=<MeanBackward1>) 2300
# tensor(1.0506, grad_fn=<MeanBackward1>) 2400
# tensor(0.9879, grad_fn=<MeanBackward1>) 2500
# tensor(1.3450, grad_fn=<MeanBackward1>) 2600
# tensor(1.0018, grad_fn=<MeanBackward1>) 2700
# tensor(0.6043, grad_fn=<MeanBackward1>) 2800
# tensor(0.5350, grad_fn=<MeanBackward1>) 2900
# tensor(1.0868, grad_fn=<MeanBackward1>) 3000
# tensor(0.4605, grad_fn=<MeanBackward1>) 3100
# tensor(0.6607, grad_fn=<MeanBackward1>) 3200
# tensor(1.1109, grad_fn=<MeanBackward1>) 3300
# tensor(0.6057, grad_fn=<MeanBackward1>) 3400
# tensor(1.3502, grad_fn=<MeanBackward1>) 3500
# tensor(0.7275, grad_fn=<MeanBackward1>) 3600
# tensor(0.6172, grad_fn=<MeanBackward1>) 3700
# tensor(2.0583, grad_fn=<MeanBackward1>) 3800
# tensor(0.5784, grad_fn=<MeanBackward1>) 3900
# tensor(8.4292, grad_fn=<MeanBackward1>) 4000
# tensor(2.0212, grad_fn=<MeanBackward1>) 4100
# tensor(7.3877, grad_fn=<MeanBackward1>) 4200
# tensor(2.0445, grad_fn=<MeanBackward1>) 4300
# tensor(1.0322, grad_fn=<MeanBackward1>) 4400
# tensor(0.5972, grad_fn=<MeanBackward1>) 4500
# tensor(0.7310, grad_fn=<MeanBackward1>) 4600
# tensor(1.3279, grad_fn=<MeanBackward1>) 4700
# tensor(0.6622, grad_fn=<MeanBackward1>) 4800
# tensor(2.0405, grad_fn=<MeanBackward1>) 4900
# tensor(1.5849, grad_fn=<MeanBackward1>) 5000
# tensor(0.7536, grad_fn=<MeanBackward1>) 5100
# tensor(0.5731, grad_fn=<MeanBackward1>) 5200
# tensor(1.2483, grad_fn=<MeanBackward1>) 5300
# tensor(0.7565, grad_fn=<MeanBackward1>) 5400
# tensor(0.5108, grad_fn=<MeanBackward1>) 5500
# tensor(1.0949, grad_fn=<MeanBackward1>) 5600
# tensor(1.3100, grad_fn=<MeanBackward1>) 5700
# tensor(1.3282, grad_fn=<MeanBackward1>) 5800
# tensor(0.8883, grad_fn=<MeanBackward1>) 5900
# tensor(6.0083, grad_fn=<MeanBackward1>) 6000
# tensor(0.5643, grad_fn=<MeanBackward1>) 6100
# tensor(1.1435, grad_fn=<MeanBackward1>) 6200
# tensor(1.0214, grad_fn=<MeanBackward1>) 6300
# tensor(1.1115, grad_fn=<MeanBackward1>) 6400
# tensor(0.7643, grad_fn=<MeanBackward1>) 6500
# tensor(0.7677, grad_fn=<MeanBackward1>) 6600
# tensor(3.6336, grad_fn=<MeanBackward1>) 6700
# tensor(16.1059, grad_fn=<MeanBackward1>) 6800
# tensor(3.1007, grad_fn=<MeanBackward1>) 6900
# tensor(2.1206, grad_fn=<MeanBackward1>) 7000
# tensor(0.8223, grad_fn=<MeanBackward1>) 7100
# tensor(2.3952, grad_fn=<MeanBackward1>) 7200
# tensor(0.8765, grad_fn=<MeanBackward1>) 7300
# tensor(0.6451, grad_fn=<MeanBackward1>) 7400
# tensor(1.2583, grad_fn=<MeanBackward1>) 7500
# tensor(14.1112, grad_fn=<MeanBackward1>) 7600
# tensor(2.3408, grad_fn=<MeanBackward1>) 7700
# tensor(2.5598, grad_fn=<MeanBackward1>) 7800
# tensor(2.1984, grad_fn=<MeanBackward1>) 7900
# tensor(4.7394, grad_fn=<MeanBackward1>) 8000
# tensor(0.7196, grad_fn=<MeanBackward1>) 8100
# tensor(1.5452, grad_fn=<MeanBackward1>) 8200
# tensor(3.6721, grad_fn=<MeanBackward1>) 8300
# tensor(0.7199, grad_fn=<MeanBackward1>) 8400
# tensor(1.0323, grad_fn=<MeanBackward1>) 8500
# tensor(0.8750, grad_fn=<MeanBackward1>) 8600
# tensor(0.8414, grad_fn=<MeanBackward1>) 8700
# tensor(0.4621, grad_fn=<MeanBackward1>) 8800
# tensor(1.0028, grad_fn=<MeanBackward1>) 8900
# tensor(0.8882, grad_fn=<MeanBackward1>) 9000
# tensor(1.0183, grad_fn=<MeanBackward1>) 9100
# tensor(0.9304, grad_fn=<MeanBackward1>) 9200
# tensor(0.8618, grad_fn=<MeanBackward1>) 9300
# tensor(1.2978, grad_fn=<MeanBackward1>) 9400
# tensor(0.3809, grad_fn=<MeanBackward1>) 9500
# tensor(0.5234, grad_fn=<MeanBackward1>) 9600
# tensor(1.0284, grad_fn=<MeanBackward1>) 9700
# tensor(1.0449, grad_fn=<MeanBackward1>) 9800
# tensor(2.3586, grad_fn=<MeanBackward1>) 9900
# tensor(1.4282, grad_fn=<MeanBackward1>) 10000
# tensor(0.7968, grad_fn=<MeanBackward1>) 10100
# tensor(1.6772, grad_fn=<MeanBackward1>) 10200
# tensor(1.9000, grad_fn=<MeanBackward1>) 10300
# tensor(0.6393, grad_fn=<MeanBackward1>) 10400
# tensor(0.9886, grad_fn=<MeanBackward1>) 10500
# tensor(0.6151, grad_fn=<MeanBackward1>) 10600
# tensor(4.5487, grad_fn=<MeanBackward1>) 10700
# tensor(7.8924, grad_fn=<MeanBackward1>) 10800
# tensor(0.5217, grad_fn=<MeanBackward1>) 10900
# tensor(1.9070, grad_fn=<MeanBackward1>) 11000
# tensor(0.7891, grad_fn=<MeanBackward1>) 11100
# tensor(2.4684, grad_fn=<MeanBackward1>) 11200
# tensor(1.1092, grad_fn=<MeanBackward1>) 11300
# tensor(0.5059, grad_fn=<MeanBackward1>) 11400
# tensor(6.3665, grad_fn=<MeanBackward1>) 11500
# tensor(1.1622, grad_fn=<MeanBackward1>) 11600
# tensor(1.5633, grad_fn=<MeanBackward1>) 11700
# tensor(1.1935, grad_fn=<MeanBackward1>) 11800
# tensor(0.5172, grad_fn=<MeanBackward1>) 11900
# tensor(0.4275, grad_fn=<MeanBackward1>) 12000
# tensor(0.9011, grad_fn=<MeanBackward1>) 12100
# tensor(1.4350, grad_fn=<MeanBackward1>) 12200
# tensor(1.4824, grad_fn=<MeanBackward1>) 12300
# tensor(0.8775, grad_fn=<MeanBackward1>) 12400
# tensor(0.8108, grad_fn=<MeanBackward1>) 12500
# tensor(1.2542, grad_fn=<MeanBackward1>) 12600
# tensor(0.6182, grad_fn=<MeanBackward1>) 12700
# tensor(0.5434, grad_fn=<MeanBackward1>) 12800
# tensor(1.1484, grad_fn=<MeanBackward1>) 12900
# tensor(1.1023, grad_fn=<MeanBackward1>) 13000
# tensor(0.6285, grad_fn=<MeanBackward1>) 13100
# tensor(0.8430, grad_fn=<MeanBackward1>) 13200
# tensor(2.3500, grad_fn=<MeanBackward1>) 13300
# tensor(1.0889, grad_fn=<MeanBackward1>) 13400
# tensor(0.7554, grad_fn=<MeanBackward1>) 13500
# tensor(0.7728, grad_fn=<MeanBackward1>) 13600
# tensor(0.5791, grad_fn=<MeanBackward1>) 13700
# tensor(1.0631, grad_fn=<MeanBackward1>) 13800
# tensor(1.8694, grad_fn=<MeanBackward1>) 13900
# tensor(0.6158, grad_fn=<MeanBackward1>) 14000
# tensor(1.4249, grad_fn=<MeanBackward1>) 14100
# tensor(0.9067, grad_fn=<MeanBackward1>) 14200
# tensor(0.6729, grad_fn=<MeanBackward1>) 14300
# tensor(0.9119, grad_fn=<MeanBackward1>) 14400
# tensor(1.7160, grad_fn=<MeanBackward1>) 14500
# tensor(1.0216, grad_fn=<MeanBackward1>) 14600
# tensor(0.5467, grad_fn=<MeanBackward1>) 14700
# tensor(1.0476, grad_fn=<MeanBackward1>) 14800
# tensor(1.7022, grad_fn=<MeanBackward1>) 14900
# tensor(1.7610, grad_fn=<MeanBackward1>) 15000
# tensor(1.2847, grad_fn=<MeanBackward1>) 15100
# tensor(2.4755, grad_fn=<MeanBackward1>) 15200
# tensor(1.5655, grad_fn=<MeanBackward1>) 15300
# tensor(1.5640, grad_fn=<MeanBackward1>) 15400
# tensor(1.6980, grad_fn=<MeanBackward1>) 15500
# tensor(0.7551, grad_fn=<MeanBackward1>) 15600
# tensor(1.7816, grad_fn=<MeanBackward1>) 15700
# tensor(0.4444, grad_fn=<MeanBackward1>) 15800
# tensor(1.8167, grad_fn=<MeanBackward1>) 15900
# tensor(1.1813, grad_fn=<MeanBackward1>) 16000
# tensor(0.4409, grad_fn=<MeanBackward1>) 16100
# tensor(0.5760, grad_fn=<MeanBackward1>) 16200
# tensor(0.8406, grad_fn=<MeanBackward1>) 16300
# tensor(0.8225, grad_fn=<MeanBackward1>) 16400
# tensor(1.0171, grad_fn=<MeanBackward1>) 16500
# tensor(1.5723, grad_fn=<MeanBackward1>) 16600
# tensor(0.4379, grad_fn=<MeanBackward1>) 16700
# tensor(2.5488, grad_fn=<MeanBackward1>) 16800
# tensor(1.2600, grad_fn=<MeanBackward1>) 16900
# tensor(0.6843, grad_fn=<MeanBackward1>) 17000
# tensor(0.5332, grad_fn=<MeanBackward1>) 17100
# tensor(0.6570, grad_fn=<MeanBackward1>) 17200
# tensor(1.3502, grad_fn=<MeanBackward1>) 17300
# tensor(2.2272, grad_fn=<MeanBackward1>) 17400
# tensor(0.7522, grad_fn=<MeanBackward1>) 17500
# tensor(1.1268, grad_fn=<MeanBackward1>) 17600
# tensor(1.3089, grad_fn=<MeanBackward1>) 17700
# tensor(0.6814, grad_fn=<MeanBackward1>) 17800
# tensor(0.9818, grad_fn=<MeanBackward1>) 17900
# tensor(1.9722, grad_fn=<MeanBackward1>) 18000
# tensor(1.4935, grad_fn=<MeanBackward1>) 18100
# tensor(0.8271, grad_fn=<MeanBackward1>) 18200
# tensor(0.7411, grad_fn=<MeanBackward1>) 18300
# tensor(0.7190, grad_fn=<MeanBackward1>) 18400
# tensor(0.8018, grad_fn=<MeanBackward1>) 18500
# tensor(1.1599, grad_fn=<MeanBackward1>) 18600
# tensor(1.6382, grad_fn=<MeanBackward1>) 18700
# tensor(0.8211, grad_fn=<MeanBackward1>) 18800
# tensor(0.6501, grad_fn=<MeanBackward1>) 18900
# tensor(0.4302, grad_fn=<MeanBackward1>) 19000
# tensor(0.5876, grad_fn=<MeanBackward1>) 19100
# tensor(0.4538, grad_fn=<MeanBackward1>) 19200
# tensor(0.4508, grad_fn=<MeanBackward1>) 19300
# tensor(0.6194, grad_fn=<MeanBackward1>) 19400
# tensor(1.0474, grad_fn=<MeanBackward1>) 19500
# tensor(5.2420, grad_fn=<MeanBackward1>) 19600
# tensor(0.7971, grad_fn=<MeanBackward1>) 19700
# tensor(1.5397, grad_fn=<MeanBackward1>) 19800
# tensor(0.6958, grad_fn=<MeanBackward1>) 19900
# tensor(0.6540, grad_fn=<MeanBackward1>) 20000
# tensor(0.8161, grad_fn=<MeanBackward1>) 20100
# tensor(0.6427, grad_fn=<MeanBackward1>) 20200
# tensor(0.6735, grad_fn=<MeanBackward1>) 20300
# tensor(1.1377, grad_fn=<MeanBackward1>) 20400
# tensor(0.7517, grad_fn=<MeanBackward1>) 20500
# tensor(1.5750, grad_fn=<MeanBackward1>) 20600
# tensor(0.9011, grad_fn=<MeanBackward1>) 20700
# tensor(2.4225, grad_fn=<MeanBackward1>) 20800
# tensor(3.4482, grad_fn=<MeanBackward1>) 20900
# tensor(0.7398, grad_fn=<MeanBackward1>) 21000
# tensor(0.8802, grad_fn=<MeanBackward1>) 21100
# tensor(0.9894, grad_fn=<MeanBackward1>) 21200
# tensor(1.0618, grad_fn=<MeanBackward1>) 21300
# tensor(0.6320, grad_fn=<MeanBackward1>) 21400
# tensor(0.8764, grad_fn=<MeanBackward1>) 21500
# tensor(1.2787, grad_fn=<MeanBackward1>) 21600
# tensor(0.7486, grad_fn=<MeanBackward1>) 21700
# tensor(0.9370, grad_fn=<MeanBackward1>) 21800
# tensor(1.1621, grad_fn=<MeanBackward1>) 21900
# tensor(0.5309, grad_fn=<MeanBackward1>) 22000
# tensor(2.2362, grad_fn=<MeanBackward1>) 22100
# tensor(1.1397, grad_fn=<MeanBackward1>) 22200
# tensor(1.4154, grad_fn=<MeanBackward1>) 22300
# tensor(0.5637, grad_fn=<MeanBackward1>) 22400
# tensor(0.8420, grad_fn=<MeanBackward1>) 22500
# tensor(0.7067, grad_fn=<MeanBackward1>) 22600
# tensor(0.6925, grad_fn=<MeanBackward1>) 22700
# tensor(1.0904, grad_fn=<MeanBackward1>) 22800
# tensor(0.7084, grad_fn=<MeanBackward1>) 22900
# tensor(1.6131, grad_fn=<MeanBackward1>) 23000
# tensor(1.3636, grad_fn=<MeanBackward1>) 23100
# tensor(0.7165, grad_fn=<MeanBackward1>) 23200
# tensor(0.6506, grad_fn=<MeanBackward1>) 23300
# tensor(5.7800, grad_fn=<MeanBackward1>) 23400
# tensor(0.5840, grad_fn=<MeanBackward1>) 23500
# tensor(1.9655, grad_fn=<MeanBackward1>) 23600
# tensor(1.0536, grad_fn=<MeanBackward1>) 23700
# tensor(0.7114, grad_fn=<MeanBackward1>) 23800
# tensor(0.8256, grad_fn=<MeanBackward1>) 23900
# tensor(1.5074, grad_fn=<MeanBackward1>) 24000
# tensor(1.2710, grad_fn=<MeanBackward1>) 24100
# tensor(0.9847, grad_fn=<MeanBackward1>) 24200
# tensor(5.3786, grad_fn=<MeanBackward1>) 24300
# tensor(0.6807, grad_fn=<MeanBackward1>) 24400
# tensor(0.6947, grad_fn=<MeanBackward1>) 24500
# tensor(0.9685, grad_fn=<MeanBackward1>) 24600
# tensor(0.5224, grad_fn=<MeanBackward1>) 24700
# tensor(1.0877, grad_fn=<MeanBackward1>) 24800
# tensor(0.5599, grad_fn=<MeanBackward1>) 24900
# tensor(0.7619, grad_fn=<MeanBackward1>) 25000
# tensor(0.9882, grad_fn=<MeanBackward1>) 25100
# tensor(0.5676, grad_fn=<MeanBackward1>) 25200
# tensor(1.2319, grad_fn=<MeanBackward1>) 25300
# tensor(0.6365, grad_fn=<MeanBackward1>) 25400
# tensor(0.5300, grad_fn=<MeanBackward1>) 25500
# tensor(3.3426, grad_fn=<MeanBackward1>) 25600
# tensor(0.6442, grad_fn=<MeanBackward1>) 25700
# tensor(0.6543, grad_fn=<MeanBackward1>) 25800
# tensor(0.5184, grad_fn=<MeanBackward1>) 25900
# tensor(0.4987, grad_fn=<MeanBackward1>) 26000
# tensor(1.0990, grad_fn=<MeanBackward1>) 26100
# tensor(0.5332, grad_fn=<MeanBackward1>) 26200
# tensor(0.7598, grad_fn=<MeanBackward1>) 26300
# tensor(0.6194, grad_fn=<MeanBackward1>) 26400
# tensor(0.8146, grad_fn=<MeanBackward1>) 26500
# tensor(2.1044, grad_fn=<MeanBackward1>) 26600
# tensor(5.6923, grad_fn=<MeanBackward1>) 26700
# tensor(0.6532, grad_fn=<MeanBackward1>) 26800
# tensor(0.6102, grad_fn=<MeanBackward1>) 26900
# tensor(0.6771, grad_fn=<MeanBackward1>) 27000
# tensor(0.7490, grad_fn=<MeanBackward1>) 27100
# tensor(0.3406, grad_fn=<MeanBackward1>) 27200
# tensor(4.0000, grad_fn=<MeanBackward1>) 27300
# tensor(0.6494, grad_fn=<MeanBackward1>) 27400
# tensor(1.5600, grad_fn=<MeanBackward1>) 27500
# tensor(0.6977, grad_fn=<MeanBackward1>) 27600
# tensor(0.7461, grad_fn=<MeanBackward1>) 27700
# tensor(0.6696, grad_fn=<MeanBackward1>) 27800
# tensor(0.8109, grad_fn=<MeanBackward1>) 27900
# tensor(0.9852, grad_fn=<MeanBackward1>) 28000
# tensor(0.5593, grad_fn=<MeanBackward1>) 28100
# tensor(0.8999, grad_fn=<MeanBackward1>) 28200
# tensor(0.7495, grad_fn=<MeanBackward1>) 28300
# tensor(2.4873, grad_fn=<MeanBackward1>) 28400
# tensor(0.6241, grad_fn=<MeanBackward1>) 28500
# tensor(0.7044, grad_fn=<MeanBackward1>) 28600
# tensor(1.7242, grad_fn=<MeanBackward1>) 28700
# tensor(0.8878, grad_fn=<MeanBackward1>) 28800
# tensor(1.0165, grad_fn=<MeanBackward1>) 28900
# tensor(0.6915, grad_fn=<MeanBackward1>) 29000
# tensor(1.6628, grad_fn=<MeanBackward1>) 29100
# tensor(4.2443, grad_fn=<MeanBackward1>) 29200
# tensor(2.2377, grad_fn=<MeanBackward1>) 29300
# tensor(1.1382, grad_fn=<MeanBackward1>) 29400
# tensor(1.9450, grad_fn=<MeanBackward1>) 29500
# tensor(0.6994, grad_fn=<MeanBackward1>) 29600
# tensor(1.2673, grad_fn=<MeanBackward1>) 29700
# tensor(0.9831, grad_fn=<MeanBackward1>) 29800
# tensor(0.8666, grad_fn=<MeanBackward1>) 29900
# tensor(1.2359, grad_fn=<MeanBackward1>) 30000
# tensor(9.9876, grad_fn=<MeanBackward1>) 30100
# tensor(0.7140, grad_fn=<MeanBackward1>) 30200
# tensor(1.9634, grad_fn=<MeanBackward1>) 30300
# tensor(2.9046, grad_fn=<MeanBackward1>) 30400
# tensor(0.8895, grad_fn=<MeanBackward1>) 30500
# tensor(0.6646, grad_fn=<MeanBackward1>) 30600
# tensor(1.6212, grad_fn=<MeanBackward1>) 30700
# tensor(0.6762, grad_fn=<MeanBackward1>) 30800
# tensor(0.6767, grad_fn=<MeanBackward1>) 30900
# tensor(1.0957, grad_fn=<MeanBackward1>) 31000
# tensor(1.6207, grad_fn=<MeanBackward1>) 31100
# tensor(0.5072, grad_fn=<MeanBackward1>) 31200
# tensor(2.6444, grad_fn=<MeanBackward1>) 31300
# tensor(19.9598, grad_fn=<MeanBackward1>) 31400
# tensor(2.8020, grad_fn=<MeanBackward1>) 31500
# tensor(0.9003, grad_fn=<MeanBackward1>) 31600
# tensor(0.6346, grad_fn=<MeanBackward1>) 31700
# tensor(1.2384, grad_fn=<MeanBackward1>) 31800
# tensor(7.5657, grad_fn=<MeanBackward1>) 31900
# tensor(0.7003, grad_fn=<MeanBackward1>) 32000
# tensor(1.6526, grad_fn=<MeanBackward1>) 32100
# tensor(2.3508, grad_fn=<MeanBackward1>) 32200
# tensor(1.9359, grad_fn=<MeanBackward1>) 32300
# tensor(0.5887, grad_fn=<MeanBackward1>) 32400
# tensor(0.6341, grad_fn=<MeanBackward1>) 32500
# tensor(0.7292, grad_fn=<MeanBackward1>) 32600
# tensor(0.8966, grad_fn=<MeanBackward1>) 32700
# tensor(1.5330, grad_fn=<MeanBackward1>) 32800
# tensor(0.4996, grad_fn=<MeanBackward1>) 32900
# tensor(1.1150, grad_fn=<MeanBackward1>) 33000
# tensor(0.7259, grad_fn=<MeanBackward1>) 33100
# tensor(1.9954, grad_fn=<MeanBackward1>) 33200
# tensor(0.4031, grad_fn=<MeanBackward1>) 33300
# tensor(0.9958, grad_fn=<MeanBackward1>) 33400
# tensor(0.5006, grad_fn=<MeanBackward1>) 33500
# tensor(1.8232, grad_fn=<MeanBackward1>) 33600
# tensor(1.2721, grad_fn=<MeanBackward1>) 33700
# tensor(1.5935, grad_fn=<MeanBackward1>) 33800
# tensor(0.9194, grad_fn=<MeanBackward1>) 33900
# tensor(0.8629, grad_fn=<MeanBackward1>) 34000
# tensor(0.6909, grad_fn=<MeanBackward1>) 34100
# tensor(0.6338, grad_fn=<MeanBackward1>) 34200
# tensor(1.8899, grad_fn=<MeanBackward1>) 34300
# tensor(1.1346, grad_fn=<MeanBackward1>) 34400
# tensor(141.1790, grad_fn=<MeanBackward1>) 34500
# tensor(5.5921, grad_fn=<MeanBackward1>) 34600
# tensor(0.5972, grad_fn=<MeanBackward1>) 34700
# tensor(0.7912, grad_fn=<MeanBackward1>) 34800
# tensor(0.4244, grad_fn=<MeanBackward1>) 34900
# tensor(0.7312, grad_fn=<MeanBackward1>) 35000
# tensor(0.9577, grad_fn=<MeanBackward1>) 35100
# tensor(1.9888, grad_fn=<MeanBackward1>) 35200
# tensor(0.8935, grad_fn=<MeanBackward1>) 35300
# tensor(0.8837, grad_fn=<MeanBackward1>) 35400
# tensor(0.6194, grad_fn=<MeanBackward1>) 35500
# tensor(1.3797, grad_fn=<MeanBackward1>) 35600
# tensor(0.6877, grad_fn=<MeanBackward1>) 35700
# tensor(1.3465, grad_fn=<MeanBackward1>) 35800
# tensor(4.2075, grad_fn=<MeanBackward1>) 35900
# tensor(0.7418, grad_fn=<MeanBackward1>) 36000
# tensor(1.4262, grad_fn=<MeanBackward1>) 36100
# tensor(1.3999, grad_fn=<MeanBackward1>) 36200
# tensor(0.5936, grad_fn=<MeanBackward1>) 36300
# tensor(0.4725, grad_fn=<MeanBackward1>) 36400
# tensor(0.7570, grad_fn=<MeanBackward1>) 36500
# tensor(0.9084, grad_fn=<MeanBackward1>) 36600
# tensor(0.5297, grad_fn=<MeanBackward1>) 36700
# tensor(0.6662, grad_fn=<MeanBackward1>) 36800
# tensor(0.4041, grad_fn=<MeanBackward1>) 36900
# tensor(1.1405, grad_fn=<MeanBackward1>) 37000
# tensor(0.4661, grad_fn=<MeanBackward1>) 37100
# tensor(2.7621, grad_fn=<MeanBackward1>) 37200
# tensor(0.9092, grad_fn=<MeanBackward1>) 37300
# tensor(0.7908, grad_fn=<MeanBackward1>) 37400
# tensor(0.7563, grad_fn=<MeanBackward1>) 37500
# tensor(0.7978, grad_fn=<MeanBackward1>) 37600
# tensor(0.6888, grad_fn=<MeanBackward1>) 37700
# tensor(1.8349, grad_fn=<MeanBackward1>) 37800
# tensor(1.5246, grad_fn=<MeanBackward1>) 37900
# tensor(2.2601, grad_fn=<MeanBackward1>) 38000
# tensor(0.7595, grad_fn=<MeanBackward1>) 38100
# tensor(2.4167, grad_fn=<MeanBackward1>) 38200
# tensor(1.8973, grad_fn=<MeanBackward1>) 38300
# tensor(0.5465, grad_fn=<MeanBackward1>) 38400
# tensor(0.8807, grad_fn=<MeanBackward1>) 38500
# tensor(0.7017, grad_fn=<MeanBackward1>) 38600
# tensor(1.0825, grad_fn=<MeanBackward1>) 38700
# tensor(0.7778, grad_fn=<MeanBackward1>) 38800
# tensor(0.6653, grad_fn=<MeanBackward1>) 38900
# tensor(0.3124, grad_fn=<MeanBackward1>) 39000
# tensor(1.2814, grad_fn=<MeanBackward1>) 39100
# tensor(0.8114, grad_fn=<MeanBackward1>) 39200
# tensor(0.4710, grad_fn=<MeanBackward1>) 39300
# tensor(1.4868, grad_fn=<MeanBackward1>) 39400
# tensor(0.7186, grad_fn=<MeanBackward1>) 39500
# tensor(1.5794, grad_fn=<MeanBackward1>) 39600
# tensor(0.8071, grad_fn=<MeanBackward1>) 39700
# tensor(0.6447, grad_fn=<MeanBackward1>) 39800
# tensor(0.7610, grad_fn=<MeanBackward1>) 39900
# tensor(0.8125, grad_fn=<MeanBackward1>) 40000
# tensor(9.6692, grad_fn=<MeanBackward1>) 40100
# tensor(0.3670, grad_fn=<MeanBackward1>) 40200
# tensor(0.5607, grad_fn=<MeanBackward1>) 40300
# tensor(0.6267, grad_fn=<MeanBackward1>) 40400
# tensor(3.5233, grad_fn=<MeanBackward1>) 40500
# tensor(1.0434, grad_fn=<MeanBackward1>) 40600
# tensor(8.8605, grad_fn=<MeanBackward1>) 40700
# tensor(0.9552, grad_fn=<MeanBackward1>) 40800
# tensor(0.8224, grad_fn=<MeanBackward1>) 40900
# tensor(0.5383, grad_fn=<MeanBackward1>) 41000
# tensor(18.2807, grad_fn=<MeanBackward1>) 41100
# tensor(0.9286, grad_fn=<MeanBackward1>) 41200
# tensor(3.0428, grad_fn=<MeanBackward1>) 41300
# tensor(0.5056, grad_fn=<MeanBackward1>) 41400
# tensor(0.6035, grad_fn=<MeanBackward1>) 41500
# tensor(1.2927, grad_fn=<MeanBackward1>) 41600
# tensor(0.5213, grad_fn=<MeanBackward1>) 41700
# tensor(1.6141, grad_fn=<MeanBackward1>) 41800
# tensor(1.4990, grad_fn=<MeanBackward1>) 41900
# tensor(0.7611, grad_fn=<MeanBackward1>) 42000
# tensor(0.9205, grad_fn=<MeanBackward1>) 42100
# tensor(1.0198, grad_fn=<MeanBackward1>) 42200
# tensor(0.4319, grad_fn=<MeanBackward1>) 42300
# tensor(0.7361, grad_fn=<MeanBackward1>) 42400
# tensor(0.7645, grad_fn=<MeanBackward1>) 42500
# tensor(2.5711, grad_fn=<MeanBackward1>) 42600
# tensor(0.8895, grad_fn=<MeanBackward1>) 42700
# tensor(0.6484, grad_fn=<MeanBackward1>) 42800
# tensor(0.5010, grad_fn=<MeanBackward1>) 42900
# tensor(0.5461, grad_fn=<MeanBackward1>) 43000
# tensor(1.0221, grad_fn=<MeanBackward1>) 43100
# tensor(1.6734, grad_fn=<MeanBackward1>) 43200
# tensor(4.2122, grad_fn=<MeanBackward1>) 43300
# tensor(0.4265, grad_fn=<MeanBackward1>) 43400
# tensor(1.3683, grad_fn=<MeanBackward1>) 43500
# tensor(0.5789, grad_fn=<MeanBackward1>) 43600
# tensor(0.6867, grad_fn=<MeanBackward1>) 43700
# tensor(0.8027, grad_fn=<MeanBackward1>) 43800
# tensor(7.0974, grad_fn=<MeanBackward1>) 43900
# tensor(0.3255, grad_fn=<MeanBackward1>) 44000
# tensor(0.6004, grad_fn=<MeanBackward1>) 44100
# tensor(0.7890, grad_fn=<MeanBackward1>) 44200
# tensor(1.1447, grad_fn=<MeanBackward1>) 44300
# tensor(0.9278, grad_fn=<MeanBackward1>) 44400
# tensor(0.9313, grad_fn=<MeanBackward1>) 44500
# tensor(0.6411, grad_fn=<MeanBackward1>) 44600
# tensor(3.7015, grad_fn=<MeanBackward1>) 44700
# tensor(1.0108, grad_fn=<MeanBackward1>) 44800
# tensor(1.2507, grad_fn=<MeanBackward1>) 44900
# tensor(1.0658, grad_fn=<MeanBackward1>) 45000
# tensor(1.0064, grad_fn=<MeanBackward1>) 45100
# tensor(0.6682, grad_fn=<MeanBackward1>) 45200
# tensor(1.0089, grad_fn=<MeanBackward1>) 45300
# tensor(1.1654, grad_fn=<MeanBackward1>) 45400
# tensor(1.7793, grad_fn=<MeanBackward1>) 45500
# tensor(1.9242, grad_fn=<MeanBackward1>) 45600
# tensor(0.4851, grad_fn=<MeanBackward1>) 45700
# tensor(0.4637, grad_fn=<MeanBackward1>) 45800
# tensor(0.6635, grad_fn=<MeanBackward1>) 45900
# tensor(1.3862, grad_fn=<MeanBackward1>) 46000
# tensor(1.9886, grad_fn=<MeanBackward1>) 46100
# tensor(1.2381, grad_fn=<MeanBackward1>) 46200
# tensor(1.2481, grad_fn=<MeanBackward1>) 46300
# tensor(1.8549, grad_fn=<MeanBackward1>) 46400
# tensor(0.5804, grad_fn=<MeanBackward1>) 46500
# tensor(0.3846, grad_fn=<MeanBackward1>) 46600
# tensor(1.2814, grad_fn=<MeanBackward1>) 46700
# tensor(1.0438, grad_fn=<MeanBackward1>) 46800
# tensor(1.0555, grad_fn=<MeanBackward1>) 46900
# tensor(0.6530, grad_fn=<MeanBackward1>) 47000
# tensor(0.4540, grad_fn=<MeanBackward1>) 47100
# tensor(0.5547, grad_fn=<MeanBackward1>) 47200
# tensor(0.9794, grad_fn=<MeanBackward1>) 47300
# tensor(0.6658, grad_fn=<MeanBackward1>) 47400
# tensor(0.4884, grad_fn=<MeanBackward1>) 47500
# tensor(0.7091, grad_fn=<MeanBackward1>) 47600
# tensor(2.5975, grad_fn=<MeanBackward1>) 47700
# tensor(1.4287, grad_fn=<MeanBackward1>) 47800
# tensor(0.6786, grad_fn=<MeanBackward1>) 47900
# tensor(1.3862, grad_fn=<MeanBackward1>) 48000
# tensor(0.9850, grad_fn=<MeanBackward1>) 48100
# tensor(0.4853, grad_fn=<MeanBackward1>) 48200
# tensor(1.6248, grad_fn=<MeanBackward1>) 48300
# tensor(0.6506, grad_fn=<MeanBackward1>) 48400
# tensor(0.8734, grad_fn=<MeanBackward1>) 48500
# tensor(2.4694, grad_fn=<MeanBackward1>) 48600
# tensor(7.6706, grad_fn=<MeanBackward1>) 48700
# tensor(0.9801, grad_fn=<MeanBackward1>) 48800
# tensor(1.4634, grad_fn=<MeanBackward1>) 48900
# tensor(0.3629, grad_fn=<MeanBackward1>) 49000
# tensor(0.7875, grad_fn=<MeanBackward1>) 49100
# tensor(0.8718, grad_fn=<MeanBackward1>) 49200
# tensor(0.7253, grad_fn=<MeanBackward1>) 49300
# tensor(0.6495, grad_fn=<MeanBackward1>) 49400
# tensor(1.0106, grad_fn=<MeanBackward1>) 49500
# tensor(7.4731, grad_fn=<MeanBackward1>) 49600
# tensor(0.9443, grad_fn=<MeanBackward1>) 49700
# tensor(1.5972, grad_fn=<MeanBackward1>) 49800
# tensor(0.7213, grad_fn=<MeanBackward1>) 49900
# tensor(0.5128, grad_fn=<MeanBackward1>) 50000
# tensor(0.9495, grad_fn=<MeanBackward1>) 50100
# tensor(0.8047, grad_fn=<MeanBackward1>) 50200
# tensor(1.7967, grad_fn=<MeanBackward1>) 50300
# tensor(0.5864, grad_fn=<MeanBackward1>) 50400
# tensor(0.6867, grad_fn=<MeanBackward1>) 50500
# tensor(10.8658, grad_fn=<MeanBackward1>) 50600
# tensor(0.7237, grad_fn=<MeanBackward1>) 50700
# tensor(9.4445, grad_fn=<MeanBackward1>) 50800
# tensor(0.5108, grad_fn=<MeanBackward1>) 50900
# tensor(8.4018, grad_fn=<MeanBackward1>) 51000
# tensor(0.9643, grad_fn=<MeanBackward1>) 51100
# tensor(0.7399, grad_fn=<MeanBackward1>) 51200
# tensor(0.7272, grad_fn=<MeanBackward1>) 51300
# tensor(0.5014, grad_fn=<MeanBackward1>) 51400
# tensor(2.9037, grad_fn=<MeanBackward1>) 51500
# tensor(0.8533, grad_fn=<MeanBackward1>) 51600
# tensor(1.3793, grad_fn=<MeanBackward1>) 51700
# tensor(1.5717, grad_fn=<MeanBackward1>) 51800
# tensor(1.3790, grad_fn=<MeanBackward1>) 51900
# tensor(0.7073, grad_fn=<MeanBackward1>) 52000
# tensor(1.9121, grad_fn=<MeanBackward1>) 52100
# tensor(0.6732, grad_fn=<MeanBackward1>) 52200
# tensor(48.4280, grad_fn=<MeanBackward1>) 52300
# tensor(0.5535, grad_fn=<MeanBackward1>) 52400
# tensor(1.9617, grad_fn=<MeanBackward1>) 52500
# tensor(0.5987, grad_fn=<MeanBackward1>) 52600
# tensor(0.7919, grad_fn=<MeanBackward1>) 52700
# tensor(2.5076, grad_fn=<MeanBackward1>) 52800
# tensor(9.4659, grad_fn=<MeanBackward1>) 52900
# tensor(1.2163, grad_fn=<MeanBackward1>) 53000
# tensor(0.9587, grad_fn=<MeanBackward1>) 53100
# tensor(0.6914, grad_fn=<MeanBackward1>) 53200
# tensor(0.7334, grad_fn=<MeanBackward1>) 53300
# tensor(1.3337, grad_fn=<MeanBackward1>) 53400
# tensor(0.9807, grad_fn=<MeanBackward1>) 53500
# tensor(3.7376, grad_fn=<MeanBackward1>) 53600
# tensor(2.7735, grad_fn=<MeanBackward1>) 53700
# tensor(4.9567, grad_fn=<MeanBackward1>) 53800
# tensor(0.7837, grad_fn=<MeanBackward1>) 53900
# tensor(2.3913, grad_fn=<MeanBackward1>) 54000
# tensor(1.9721, grad_fn=<MeanBackward1>) 54100
# tensor(1.1131, grad_fn=<MeanBackward1>) 54200
# tensor(0.4510, grad_fn=<MeanBackward1>) 54300
# tensor(0.5221, grad_fn=<MeanBackward1>) 54400
# tensor(1.1086, grad_fn=<MeanBackward1>) 54500
# tensor(0.5706, grad_fn=<MeanBackward1>) 54600
# tensor(2.1098, grad_fn=<MeanBackward1>) 54700
# tensor(0.6484, grad_fn=<MeanBackward1>) 54800
# tensor(0.7577, grad_fn=<MeanBackward1>) 54900
# tensor(1.4500, grad_fn=<MeanBackward1>) 55000
# tensor(10.4389, grad_fn=<MeanBackward1>) 55100
# tensor(2.1433, grad_fn=<MeanBackward1>) 55200
# tensor(0.7722, grad_fn=<MeanBackward1>) 55300
# tensor(1.0848, grad_fn=<MeanBackward1>) 55400
# tensor(0.6077, grad_fn=<MeanBackward1>) 55500
# tensor(0.6945, grad_fn=<MeanBackward1>) 55600
# tensor(1.4212, grad_fn=<MeanBackward1>) 55700
# tensor(1.3552, grad_fn=<MeanBackward1>) 55800
# tensor(0.6020, grad_fn=<MeanBackward1>) 55900
# tensor(10.2589, grad_fn=<MeanBackward1>) 56000
# tensor(0.7623, grad_fn=<MeanBackward1>) 56100
# tensor(0.5283, grad_fn=<MeanBackward1>) 56200
# tensor(0.7888, grad_fn=<MeanBackward1>) 56300
# tensor(0.9389, grad_fn=<MeanBackward1>) 56400
# tensor(1.1260, grad_fn=<MeanBackward1>) 56500
# tensor(2.7462, grad_fn=<MeanBackward1>) 56600
# tensor(0.8198, grad_fn=<MeanBackward1>) 56700
# tensor(0.4099, grad_fn=<MeanBackward1>) 56800
# tensor(0.8795, grad_fn=<MeanBackward1>) 56900
# tensor(0.8781, grad_fn=<MeanBackward1>) 57000
# tensor(1.1070, grad_fn=<MeanBackward1>) 57100
# tensor(1.2775, grad_fn=<MeanBackward1>) 57200
# tensor(1.4180, grad_fn=<MeanBackward1>) 57300
# tensor(1.5628, grad_fn=<MeanBackward1>) 57400
# tensor(0.6393, grad_fn=<MeanBackward1>) 57500
# tensor(10.5333, grad_fn=<MeanBackward1>) 57600
# tensor(0.5512, grad_fn=<MeanBackward1>) 57700
# tensor(0.9146, grad_fn=<MeanBackward1>) 57800
# tensor(0.6546, grad_fn=<MeanBackward1>) 57900
# tensor(0.5065, grad_fn=<MeanBackward1>) 58000
# tensor(1.2904, grad_fn=<MeanBackward1>) 58100
# tensor(0.6272, grad_fn=<MeanBackward1>) 58200
# tensor(1.3402, grad_fn=<MeanBackward1>) 58300
# tensor(0.5984, grad_fn=<MeanBackward1>) 58400
# tensor(0.5522, grad_fn=<MeanBackward1>) 58500
# tensor(0.6706, grad_fn=<MeanBackward1>) 58600
# tensor(0.6542, grad_fn=<MeanBackward1>) 58700
# tensor(3.3614, grad_fn=<MeanBackward1>) 58800
# tensor(0.4702, grad_fn=<MeanBackward1>) 58900
# tensor(0.8738, grad_fn=<MeanBackward1>) 59000
# tensor(0.8810, grad_fn=<MeanBackward1>) 59100
# tensor(0.8356, grad_fn=<MeanBackward1>) 59200
# tensor(0.8370, grad_fn=<MeanBackward1>) 59300
# tensor(2.0284, grad_fn=<MeanBackward1>) 59400
# tensor(0.8097, grad_fn=<MeanBackward1>) 59500
# tensor(0.8024, grad_fn=<MeanBackward1>) 59600
# tensor(0.4380, grad_fn=<MeanBackward1>) 59700
# tensor(0.7871, grad_fn=<MeanBackward1>) 59800
# tensor(1.6089, grad_fn=<MeanBackward1>) 59900
# tensor(0.8348, grad_fn=<MeanBackward1>) 60000
# tensor(0.6751, grad_fn=<MeanBackward1>) 60100
# tensor(1.4153, grad_fn=<MeanBackward1>) 60200
# tensor(0.9180, grad_fn=<MeanBackward1>) 60300
# tensor(3.8785, grad_fn=<MeanBackward1>) 60400
# tensor(0.6411, grad_fn=<MeanBackward1>) 60500
# tensor(3.7926, grad_fn=<MeanBackward1>) 60600
# tensor(0.4296, grad_fn=<MeanBackward1>) 60700
# tensor(0.6953, grad_fn=<MeanBackward1>) 60800
# tensor(1.0815, grad_fn=<MeanBackward1>) 60900
# tensor(0.7614, grad_fn=<MeanBackward1>) 61000
# tensor(0.6656, grad_fn=<MeanBackward1>) 61100
# tensor(1.0333, grad_fn=<MeanBackward1>) 61200
# tensor(0.6735, grad_fn=<MeanBackward1>) 61300
# tensor(1.1067, grad_fn=<MeanBackward1>) 61400
# tensor(4.7757, grad_fn=<MeanBackward1>) 61500
# tensor(0.8014, grad_fn=<MeanBackward1>) 61600
# tensor(1.0510, grad_fn=<MeanBackward1>) 61700
# tensor(29.0073, grad_fn=<MeanBackward1>) 61800
# tensor(0.7211, grad_fn=<MeanBackward1>) 61900
# tensor(3.1485, grad_fn=<MeanBackward1>) 62000
# tensor(0.4855, grad_fn=<MeanBackward1>) 62100
# tensor(0.8437, grad_fn=<MeanBackward1>) 62200
# tensor(2.0352, grad_fn=<MeanBackward1>) 62300
# tensor(1.2029, grad_fn=<MeanBackward1>) 62400
# tensor(0.4428, grad_fn=<MeanBackward1>) 62500
# tensor(0.4813, grad_fn=<MeanBackward1>) 62600
# tensor(1.2889, grad_fn=<MeanBackward1>) 62700
# tensor(2.7498, grad_fn=<MeanBackward1>) 62800
# tensor(0.6218, grad_fn=<MeanBackward1>) 62900
# tensor(1.2585, grad_fn=<MeanBackward1>) 63000
# tensor(0.8708, grad_fn=<MeanBackward1>) 63100
# tensor(0.4554, grad_fn=<MeanBackward1>) 63200
# tensor(0.7154, grad_fn=<MeanBackward1>) 63300
# tensor(0.6973, grad_fn=<MeanBackward1>) 63400
# tensor(0.7751, grad_fn=<MeanBackward1>) 63500
# tensor(2.4884, grad_fn=<MeanBackward1>) 63600
# tensor(3.0722, grad_fn=<MeanBackward1>) 63700
# tensor(0.8317, grad_fn=<MeanBackward1>) 63800
# tensor(1.4656, grad_fn=<MeanBackward1>) 63900
# tensor(0.5022, grad_fn=<MeanBackward1>) 64000
# tensor(1.0278, grad_fn=<MeanBackward1>) 64100
# tensor(1.6205, grad_fn=<MeanBackward1>) 64200
# tensor(0.8614, grad_fn=<MeanBackward1>) 64300
# tensor(0.8895, grad_fn=<MeanBackward1>) 64400
# tensor(0.8430, grad_fn=<MeanBackward1>) 64500
# tensor(0.7007, grad_fn=<MeanBackward1>) 64600
# tensor(0.9500, grad_fn=<MeanBackward1>) 64700
# tensor(0.4875, grad_fn=<MeanBackward1>) 64800
# tensor(2.5201, grad_fn=<MeanBackward1>) 64900
# tensor(3.0322, grad_fn=<MeanBackward1>) 65000
# tensor(0.7449, grad_fn=<MeanBackward1>) 65100
# tensor(1.1630, grad_fn=<MeanBackward1>) 65200
# tensor(0.6314, grad_fn=<MeanBackward1>) 65300
# tensor(0.9072, grad_fn=<MeanBackward1>) 65400
# tensor(1.3418, grad_fn=<MeanBackward1>) 65500
# tensor(1.8666, grad_fn=<MeanBackward1>) 65600
# tensor(1.9099, grad_fn=<MeanBackward1>) 65700
# tensor(0.5473, grad_fn=<MeanBackward1>) 65800
# tensor(0.7032, grad_fn=<MeanBackward1>) 65900
# tensor(0.5887, grad_fn=<MeanBackward1>) 66000
# tensor(32.8575, grad_fn=<MeanBackward1>) 66100
# tensor(0.4253, grad_fn=<MeanBackward1>) 66200
# tensor(2.0860, grad_fn=<MeanBackward1>) 66300
# tensor(1.5077, grad_fn=<MeanBackward1>) 66400
# tensor(2.1845, grad_fn=<MeanBackward1>) 66500
# tensor(0.5752, grad_fn=<MeanBackward1>) 66600
# tensor(0.5369, grad_fn=<MeanBackward1>) 66700
# tensor(0.6333, grad_fn=<MeanBackward1>) 66800
# tensor(0.4130, grad_fn=<MeanBackward1>) 66900
# tensor(1.1354, grad_fn=<MeanBackward1>) 67000
# tensor(3.1137, grad_fn=<MeanBackward1>) 67100
# tensor(1.7931, grad_fn=<MeanBackward1>) 67200
# tensor(1.3542, grad_fn=<MeanBackward1>) 67300
# tensor(3.4407, grad_fn=<MeanBackward1>) 67400
# tensor(8.9628, grad_fn=<MeanBackward1>) 67500
# tensor(0.7295, grad_fn=<MeanBackward1>) 67600
# tensor(0.8048, grad_fn=<MeanBackward1>) 67700
# tensor(1.7464, grad_fn=<MeanBackward1>) 67800
# tensor(0.4476, grad_fn=<MeanBackward1>) 67900
# tensor(0.5875, grad_fn=<MeanBackward1>) 68000
# tensor(0.4823, grad_fn=<MeanBackward1>) 68100
# tensor(0.6448, grad_fn=<MeanBackward1>) 68200
# tensor(0.5896, grad_fn=<MeanBackward1>) 68300
# tensor(2.2757, grad_fn=<MeanBackward1>) 68400
# tensor(0.6045, grad_fn=<MeanBackward1>) 68500
# tensor(0.7895, grad_fn=<MeanBackward1>) 68600
# tensor(30.0607, grad_fn=<MeanBackward1>) 68700
# tensor(1.2235, grad_fn=<MeanBackward1>) 68800
# tensor(2.4479, grad_fn=<MeanBackward1>) 68900
# tensor(2.0928, grad_fn=<MeanBackward1>) 69000
# tensor(1.0889, grad_fn=<MeanBackward1>) 69100
# tensor(0.6784, grad_fn=<MeanBackward1>) 69200
# tensor(0.7071, grad_fn=<MeanBackward1>) 69300
# tensor(2.2404, grad_fn=<MeanBackward1>) 69400
# tensor(0.5737, grad_fn=<MeanBackward1>) 69500
# tensor(1.1114, grad_fn=<MeanBackward1>) 69600
# tensor(1.1003, grad_fn=<MeanBackward1>) 69700
# tensor(1.4723, grad_fn=<MeanBackward1>) 69800
# tensor(1.4295, grad_fn=<MeanBackward1>) 69900
# tensor(3.0819, grad_fn=<MeanBackward1>) 70000
# tensor(1.8364, grad_fn=<MeanBackward1>) 70100
# tensor(0.9507, grad_fn=<MeanBackward1>) 70200
# tensor(0.5938, grad_fn=<MeanBackward1>) 70300
# tensor(0.7549, grad_fn=<MeanBackward1>) 70400
# tensor(0.6880, grad_fn=<MeanBackward1>) 70500
# tensor(0.9145, grad_fn=<MeanBackward1>) 70600
# tensor(0.9319, grad_fn=<MeanBackward1>) 70700
# tensor(0.5302, grad_fn=<MeanBackward1>) 70800
# tensor(0.8509, grad_fn=<MeanBackward1>) 70900
# tensor(0.9924, grad_fn=<MeanBackward1>) 71000
# tensor(0.8395, grad_fn=<MeanBackward1>) 71100
# tensor(1.2668, grad_fn=<MeanBackward1>) 71200
# tensor(19.8480, grad_fn=<MeanBackward1>) 71300
# tensor(8.4740, grad_fn=<MeanBackward1>) 71400
# tensor(0.5634, grad_fn=<MeanBackward1>) 71500
# tensor(0.6659, grad_fn=<MeanBackward1>) 71600
# tensor(0.4533, grad_fn=<MeanBackward1>) 71700
# tensor(0.6600, grad_fn=<MeanBackward1>) 71800
# tensor(1.1730, grad_fn=<MeanBackward1>) 71900
# tensor(0.6465, grad_fn=<MeanBackward1>) 72000
# tensor(1.0197, grad_fn=<MeanBackward1>) 72100
# tensor(2.0935, grad_fn=<MeanBackward1>) 72200
# tensor(0.7046, grad_fn=<MeanBackward1>) 72300
# tensor(0.5048, grad_fn=<MeanBackward1>) 72400
# tensor(0.4296, grad_fn=<MeanBackward1>) 72500
# tensor(0.5831, grad_fn=<MeanBackward1>) 72600
# tensor(1.1443, grad_fn=<MeanBackward1>) 72700
# tensor(1.2241, grad_fn=<MeanBackward1>) 72800
# tensor(0.6236, grad_fn=<MeanBackward1>) 72900
# tensor(7.6220, grad_fn=<MeanBackward1>) 73000
# tensor(1.3580, grad_fn=<MeanBackward1>) 73100
# tensor(1.0227, grad_fn=<MeanBackward1>) 73200
# tensor(1.1287, grad_fn=<MeanBackward1>) 73300
# tensor(0.8009, grad_fn=<MeanBackward1>) 73400
# tensor(2.0858, grad_fn=<MeanBackward1>) 73500
# tensor(0.6517, grad_fn=<MeanBackward1>) 73600
# tensor(0.9568, grad_fn=<MeanBackward1>) 73700
# tensor(0.5960, grad_fn=<MeanBackward1>) 73800
# tensor(2.5499, grad_fn=<MeanBackward1>) 73900
# tensor(0.6763, grad_fn=<MeanBackward1>) 74000
# tensor(0.9439, grad_fn=<MeanBackward1>) 74100
# tensor(2.1953, grad_fn=<MeanBackward1>) 74200
# tensor(0.6581, grad_fn=<MeanBackward1>) 74300
# tensor(0.3245, grad_fn=<MeanBackward1>) 74400
# tensor(1.1184, grad_fn=<MeanBackward1>) 74500
# tensor(1.1590, grad_fn=<MeanBackward1>) 74600
# tensor(0.6907, grad_fn=<MeanBackward1>) 74700
# tensor(1.0675, grad_fn=<MeanBackward1>) 74800
# tensor(1.3761, grad_fn=<MeanBackward1>) 74900
# tensor(0.5237, grad_fn=<MeanBackward1>) 75000
# tensor(1.3297, grad_fn=<MeanBackward1>) 75100
# tensor(0.9127, grad_fn=<MeanBackward1>) 75200
# tensor(0.5016, grad_fn=<MeanBackward1>) 75300
# tensor(0.6005, grad_fn=<MeanBackward1>) 75400
# tensor(0.7601, grad_fn=<MeanBackward1>) 75500
# tensor(0.4208, grad_fn=<MeanBackward1>) 75600
# tensor(1.4323, grad_fn=<MeanBackward1>) 75700
# tensor(0.6963, grad_fn=<MeanBackward1>) 75800
# tensor(0.8260, grad_fn=<MeanBackward1>) 75900
# tensor(0.6153, grad_fn=<MeanBackward1>) 76000
# tensor(0.4994, grad_fn=<MeanBackward1>) 76100
# tensor(0.8278, grad_fn=<MeanBackward1>) 76200
# tensor(1.5036, grad_fn=<MeanBackward1>) 76300
# tensor(0.6351, grad_fn=<MeanBackward1>) 76400
# tensor(3.0928, grad_fn=<MeanBackward1>) 76500
# tensor(0.8989, grad_fn=<MeanBackward1>) 76600
# tensor(0.7426, grad_fn=<MeanBackward1>) 76700
# tensor(0.9524, grad_fn=<MeanBackward1>) 76800
# tensor(0.5772, grad_fn=<MeanBackward1>) 76900
# tensor(0.7057, grad_fn=<MeanBackward1>) 77000
# tensor(1.0825, grad_fn=<MeanBackward1>) 77100
# tensor(0.5145, grad_fn=<MeanBackward1>) 77200
# tensor(0.8450, grad_fn=<MeanBackward1>) 77300
# tensor(2.5769, grad_fn=<MeanBackward1>) 77400
# tensor(1.1900, grad_fn=<MeanBackward1>) 77500
# tensor(0.8915, grad_fn=<MeanBackward1>) 77600
# tensor(3.4435, grad_fn=<MeanBackward1>) 77700
# tensor(0.4598, grad_fn=<MeanBackward1>) 77800
# tensor(0.6166, grad_fn=<MeanBackward1>) 77900
# tensor(2.7002, grad_fn=<MeanBackward1>) 78000
# tensor(0.6241, grad_fn=<MeanBackward1>) 78100
# tensor(2.4871, grad_fn=<MeanBackward1>) 78200
# tensor(2.1599, grad_fn=<MeanBackward1>) 78300
# tensor(0.9512, grad_fn=<MeanBackward1>) 78400
# tensor(1.4727, grad_fn=<MeanBackward1>) 78500
# tensor(0.3024, grad_fn=<MeanBackward1>) 78600
# tensor(1.7572, grad_fn=<MeanBackward1>) 78700
# tensor(0.6950, grad_fn=<MeanBackward1>) 78800
# tensor(1.7106, grad_fn=<MeanBackward1>) 78900
# tensor(1.1969, grad_fn=<MeanBackward1>) 79000
# tensor(0.8192, grad_fn=<MeanBackward1>) 79100
# tensor(1.0102, grad_fn=<MeanBackward1>) 79200
# tensor(1.5109, grad_fn=<MeanBackward1>) 79300
# tensor(1.4647, grad_fn=<MeanBackward1>) 79400
# tensor(0.8782, grad_fn=<MeanBackward1>) 79500
# tensor(0.4956, grad_fn=<MeanBackward1>) 79600
# tensor(0.6851, grad_fn=<MeanBackward1>) 79700
# tensor(7.5382, grad_fn=<MeanBackward1>) 79800
# tensor(1.0560, grad_fn=<MeanBackward1>) 79900
# tensor(2.3600, grad_fn=<MeanBackward1>) 80000
# tensor(2.1233, grad_fn=<MeanBackward1>) 80100
# tensor(28.5035, grad_fn=<MeanBackward1>) 80200
# tensor(0.6941, grad_fn=<MeanBackward1>) 80300
# tensor(0.7586, grad_fn=<MeanBackward1>) 80400
# tensor(1.5314, grad_fn=<MeanBackward1>) 80500
# tensor(0.7515, grad_fn=<MeanBackward1>) 80600
# tensor(0.9021, grad_fn=<MeanBackward1>) 80700
# tensor(0.4647, grad_fn=<MeanBackward1>) 80800
# tensor(0.5631, grad_fn=<MeanBackward1>) 80900
# tensor(2.1364, grad_fn=<MeanBackward1>) 81000
# tensor(1.2959, grad_fn=<MeanBackward1>) 81100
# tensor(0.7210, grad_fn=<MeanBackward1>) 81200
# tensor(0.4787, grad_fn=<MeanBackward1>) 81300
# tensor(0.9611, grad_fn=<MeanBackward1>) 81400
# tensor(0.7241, grad_fn=<MeanBackward1>) 81500
# tensor(3.7335, grad_fn=<MeanBackward1>) 81600
# tensor(0.9016, grad_fn=<MeanBackward1>) 81700
# tensor(1.9020, grad_fn=<MeanBackward1>) 81800
# tensor(2.7026, grad_fn=<MeanBackward1>) 81900
# tensor(1.6156, grad_fn=<MeanBackward1>) 82000
# tensor(6.9257, grad_fn=<MeanBackward1>) 82100
# tensor(0.7010, grad_fn=<MeanBackward1>) 82200
# tensor(0.8110, grad_fn=<MeanBackward1>) 82300
# tensor(0.5595, grad_fn=<MeanBackward1>) 82400
# tensor(0.9075, grad_fn=<MeanBackward1>) 82500
# tensor(0.5618, grad_fn=<MeanBackward1>) 82600
# tensor(1.0829, grad_fn=<MeanBackward1>) 82700
# tensor(4.9281, grad_fn=<MeanBackward1>) 82800
# tensor(0.5001, grad_fn=<MeanBackward1>) 82900
# tensor(6.0144, grad_fn=<MeanBackward1>) 83000
# tensor(1.6114, grad_fn=<MeanBackward1>) 83100
# tensor(0.3914, grad_fn=<MeanBackward1>) 83200
# tensor(0.6601, grad_fn=<MeanBackward1>) 83300
# tensor(0.8935, grad_fn=<MeanBackward1>) 83400
# tensor(0.6553, grad_fn=<MeanBackward1>) 83500
# tensor(23.0676, grad_fn=<MeanBackward1>) 83600
# tensor(0.5809, grad_fn=<MeanBackward1>) 83700
# tensor(0.6698, grad_fn=<MeanBackward1>) 83800
# tensor(0.9397, grad_fn=<MeanBackward1>) 83900
# tensor(0.8275, grad_fn=<MeanBackward1>) 84000
# tensor(0.7679, grad_fn=<MeanBackward1>) 84100
# tensor(0.6786, grad_fn=<MeanBackward1>) 84200
# tensor(0.7267, grad_fn=<MeanBackward1>) 84300
# tensor(0.7740, grad_fn=<MeanBackward1>) 84400
# tensor(0.6756, grad_fn=<MeanBackward1>) 84500
# tensor(0.7945, grad_fn=<MeanBackward1>) 84600
# tensor(0.6742, grad_fn=<MeanBackward1>) 84700
# tensor(1.2945, grad_fn=<MeanBackward1>) 84800
# tensor(1.0791, grad_fn=<MeanBackward1>) 84900
# tensor(1.2798, grad_fn=<MeanBackward1>) 85000
# tensor(1.4796, grad_fn=<MeanBackward1>) 85100
# tensor(0.4834, grad_fn=<MeanBackward1>) 85200
# tensor(3.3730, grad_fn=<MeanBackward1>) 85300
# tensor(0.7955, grad_fn=<MeanBackward1>) 85400
# tensor(0.5452, grad_fn=<MeanBackward1>) 85500
# tensor(0.7330, grad_fn=<MeanBackward1>) 85600
# tensor(0.8775, grad_fn=<MeanBackward1>) 85700
# tensor(0.4682, grad_fn=<MeanBackward1>) 85800
# tensor(0.4311, grad_fn=<MeanBackward1>) 85900
# tensor(0.5052, grad_fn=<MeanBackward1>) 86000
# tensor(0.5836, grad_fn=<MeanBackward1>) 86100
# tensor(0.6545, grad_fn=<MeanBackward1>) 86200
# tensor(2.5856, grad_fn=<MeanBackward1>) 86300
# tensor(0.5145, grad_fn=<MeanBackward1>) 86400
# tensor(0.7933, grad_fn=<MeanBackward1>) 86500
# tensor(0.9874, grad_fn=<MeanBackward1>) 86600
# tensor(1.8844, grad_fn=<MeanBackward1>) 86700
# tensor(0.4331, grad_fn=<MeanBackward1>) 86800
# tensor(0.8389, grad_fn=<MeanBackward1>) 86900
# tensor(0.8698, grad_fn=<MeanBackward1>) 87000
# tensor(3.5302, grad_fn=<MeanBackward1>) 87100
# tensor(0.6516, grad_fn=<MeanBackward1>) 87200
# tensor(0.4675, grad_fn=<MeanBackward1>) 87300
# tensor(0.7209, grad_fn=<MeanBackward1>) 87400
# tensor(0.4292, grad_fn=<MeanBackward1>) 87500
# tensor(1.5780, grad_fn=<MeanBackward1>) 87600
# tensor(0.8530, grad_fn=<MeanBackward1>) 87700
# tensor(0.5443, grad_fn=<MeanBackward1>) 87800
# tensor(1.1249, grad_fn=<MeanBackward1>) 87900
# tensor(0.9043, grad_fn=<MeanBackward1>) 88000
# tensor(0.6604, grad_fn=<MeanBackward1>) 88100
# tensor(0.6969, grad_fn=<MeanBackward1>) 88200
# tensor(0.6708, grad_fn=<MeanBackward1>) 88300
# tensor(3.1159, grad_fn=<MeanBackward1>) 88400
# tensor(1.0243, grad_fn=<MeanBackward1>) 88500
# tensor(0.9520, grad_fn=<MeanBackward1>) 88600
# tensor(0.9127, grad_fn=<MeanBackward1>) 88700
# tensor(0.8104, grad_fn=<MeanBackward1>) 88800
# tensor(0.7500, grad_fn=<MeanBackward1>) 88900
# tensor(0.7342, grad_fn=<MeanBackward1>) 89000
# tensor(1.6820, grad_fn=<MeanBackward1>) 89100
# tensor(0.6928, grad_fn=<MeanBackward1>) 89200
# tensor(1.1657, grad_fn=<MeanBackward1>) 89300
# tensor(0.4152, grad_fn=<MeanBackward1>) 89400
# tensor(1.0526, grad_fn=<MeanBackward1>) 89500
# tensor(17.2014, grad_fn=<MeanBackward1>) 89600
# tensor(0.5438, grad_fn=<MeanBackward1>) 89700
# tensor(0.9043, grad_fn=<MeanBackward1>) 89800
# tensor(1.1110, grad_fn=<MeanBackward1>) 89900
# tensor(0.8858, grad_fn=<MeanBackward1>) 90000
# tensor(0.4652, grad_fn=<MeanBackward1>) 90100
# tensor(1.7352, grad_fn=<MeanBackward1>) 90200
# tensor(0.9810, grad_fn=<MeanBackward1>) 90300
# tensor(0.5874, grad_fn=<MeanBackward1>) 90400
# tensor(1.1089, grad_fn=<MeanBackward1>) 90500
# tensor(0.4199, grad_fn=<MeanBackward1>) 90600
# tensor(0.8849, grad_fn=<MeanBackward1>) 90700
# tensor(0.3793, grad_fn=<MeanBackward1>) 90800
# tensor(0.9036, grad_fn=<MeanBackward1>) 90900
# tensor(0.8438, grad_fn=<MeanBackward1>) 91000
# tensor(1.2665, grad_fn=<MeanBackward1>) 91100
# tensor(0.5482, grad_fn=<MeanBackward1>) 91200
# tensor(0.7459, grad_fn=<MeanBackward1>) 91300
# tensor(0.4107, grad_fn=<MeanBackward1>) 91400
# tensor(1.0721, grad_fn=<MeanBackward1>) 91500
# tensor(0.8586, grad_fn=<MeanBackward1>) 91600
# tensor(0.5228, grad_fn=<MeanBackward1>) 91700
# tensor(1.1327, grad_fn=<MeanBackward1>) 91800
# tensor(0.4465, grad_fn=<MeanBackward1>) 91900
# tensor(2.8839, grad_fn=<MeanBackward1>) 92000
# tensor(1.3424, grad_fn=<MeanBackward1>) 92100
# tensor(1.0504, grad_fn=<MeanBackward1>) 92200
# tensor(2.5696, grad_fn=<MeanBackward1>) 92300
# tensor(0.9825, grad_fn=<MeanBackward1>) 92400
# tensor(1.0744, grad_fn=<MeanBackward1>) 92500
# tensor(0.8398, grad_fn=<MeanBackward1>) 92600
# tensor(0.8485, grad_fn=<MeanBackward1>) 92700
# tensor(0.5311, grad_fn=<MeanBackward1>) 92800
# tensor(0.8069, grad_fn=<MeanBackward1>) 92900
# tensor(0.7017, grad_fn=<MeanBackward1>) 93000
# tensor(7.5718, grad_fn=<MeanBackward1>) 93100
# tensor(0.7672, grad_fn=<MeanBackward1>) 93200
# tensor(0.4372, grad_fn=<MeanBackward1>) 93300
# tensor(0.9347, grad_fn=<MeanBackward1>) 93400
# tensor(0.6581, grad_fn=<MeanBackward1>) 93500
# tensor(0.9687, grad_fn=<MeanBackward1>) 93600
# tensor(0.6554, grad_fn=<MeanBackward1>) 93700
# tensor(0.6169, grad_fn=<MeanBackward1>) 93800
# tensor(1.9788, grad_fn=<MeanBackward1>) 93900
# tensor(4.6307, grad_fn=<MeanBackward1>) 94000
# tensor(0.8966, grad_fn=<MeanBackward1>) 94100
# tensor(0.8456, grad_fn=<MeanBackward1>) 94200
# tensor(2.0739, grad_fn=<MeanBackward1>) 94300
# tensor(0.6362, grad_fn=<MeanBackward1>) 94400
# tensor(5.8279, grad_fn=<MeanBackward1>) 94500
# tensor(1.5099, grad_fn=<MeanBackward1>) 94600
# tensor(1.2033, grad_fn=<MeanBackward1>) 94700
# tensor(1.6771, grad_fn=<MeanBackward1>) 94800
# tensor(0.9058, grad_fn=<MeanBackward1>) 94900
# tensor(0.6484, grad_fn=<MeanBackward1>) 95000
# tensor(0.7694, grad_fn=<MeanBackward1>) 95100
# tensor(0.6759, grad_fn=<MeanBackward1>) 95200
# tensor(1.5782, grad_fn=<MeanBackward1>) 95300
# tensor(0.7480, grad_fn=<MeanBackward1>) 95400
# tensor(23.7629, grad_fn=<MeanBackward1>) 95500
# tensor(1.4456, grad_fn=<MeanBackward1>) 95600
# tensor(0.6714, grad_fn=<MeanBackward1>) 95700
# tensor(0.6225, grad_fn=<MeanBackward1>) 95800
# tensor(0.7714, grad_fn=<MeanBackward1>) 95900
# tensor(0.4062, grad_fn=<MeanBackward1>) 96000
# tensor(23.5027, grad_fn=<MeanBackward1>) 96100
# tensor(1.1874, grad_fn=<MeanBackward1>) 96200
# tensor(1.2067, grad_fn=<MeanBackward1>) 96300
# tensor(1.0176, grad_fn=<MeanBackward1>) 96400
# tensor(0.7766, grad_fn=<MeanBackward1>) 96500
# tensor(0.6672, grad_fn=<MeanBackward1>) 96600
# tensor(0.4856, grad_fn=<MeanBackward1>) 96700
# tensor(3.0314, grad_fn=<MeanBackward1>) 96800
# tensor(0.6185, grad_fn=<MeanBackward1>) 96900
# tensor(0.6418, grad_fn=<MeanBackward1>) 97000
# tensor(2.4014, grad_fn=<MeanBackward1>) 97100
# tensor(0.5667, grad_fn=<MeanBackward1>) 97200
# tensor(0.9040, grad_fn=<MeanBackward1>) 97300
# tensor(0.8282, grad_fn=<MeanBackward1>) 97400
# tensor(0.8514, grad_fn=<MeanBackward1>) 97500
# tensor(1.4679, grad_fn=<MeanBackward1>) 97600
# tensor(0.8535, grad_fn=<MeanBackward1>) 97700
# tensor(0.8637, grad_fn=<MeanBackward1>) 97800
# tensor(0.7533, grad_fn=<MeanBackward1>) 97900
# tensor(0.5721, grad_fn=<MeanBackward1>) 98000
# tensor(0.5113, grad_fn=<MeanBackward1>) 98100
# tensor(0.5270, grad_fn=<MeanBackward1>) 98200
# tensor(0.6009, grad_fn=<MeanBackward1>) 98300
# tensor(0.5774, grad_fn=<MeanBackward1>) 98400
# tensor(1.0292, grad_fn=<MeanBackward1>) 98500
# tensor(1.5426, grad_fn=<MeanBackward1>) 98600
# tensor(1.0793, grad_fn=<MeanBackward1>) 98700
# tensor(0.5963, grad_fn=<MeanBackward1>) 98800
# tensor(0.6248, grad_fn=<MeanBackward1>) 98900
# tensor(0.4681, grad_fn=<MeanBackward1>) 99000
# tensor(0.6578, grad_fn=<MeanBackward1>) 99100
# tensor(1.0358, grad_fn=<MeanBackward1>) 99200
# tensor(0.7503, grad_fn=<MeanBackward1>) 99300
# tensor(2.8204, grad_fn=<MeanBackward1>) 99400
# tensor(1.6692, grad_fn=<MeanBackward1>) 99500
# tensor(0.4760, grad_fn=<MeanBackward1>) 99600
# tensor(2.4653, grad_fn=<MeanBackward1>) 99700
# tensor(1.4430, grad_fn=<MeanBackward1>) 99800
# tensor(0.7640, grad_fn=<MeanBackward1>) 99900

# %% [markdown]
# SDE simulation functions

# %%
# This is the solving the OU process exactly given deterministic initial conditions
def ou_dynamics(init, T):
    init = init * torch.exp(- 0.5 * T) + torch.sqrt(1-torch.exp(-T)) * torch.randn_like(init)
    return init

def reverse_sde(score, init,T,lr=0.01):
    step = int(T/lr) 
    for i in range(step,-1,-1):
        current_lr = lr
        evalpoint = torch.cat(((torch.tensor(lr*i)).repeat(init.shape[0],1),init),1)
        init = init + current_lr  * (init/2 + score(evalpoint).detach() )
        init = init + torch.randn_like(init) * np.sqrt(current_lr)
    return init


# The following is the deterministic ODE flow that can also sample from the target distribution

def reverse_ode_flow(score,init,T,lr = 0.01):
    step = int(T/lr)
    for i in range(step,-1,-1):
        current_lr = lr
        evalpoint = torch.cat(((torch.tensor(lr*i)).repeat(init.shape[0],1),init),1)
        init = init + current_lr  * (init/2 + 1/2 * score(evalpoint).detach() )
    return init

# %% [markdown]
# Sample using the score network

# %%
# Denoising the normal distribution 
samples_lang = torch.randn(10000, 2) # * (right_bound - left_bound) + left_bound
samples_lang = reverse_sde(scorenet, samples_lang,torch.tensor(T)).detach().numpy()


# Denoising samples from the training data
samples = torch.tensor(toy_data.inf_train_gen('moons', batch_size = 10000))
samples_lang_noisedtraining = samples * torch.exp(-0.5 * torch.tensor(T)) + torch.sqrt(1-torch.exp(-torch.tensor(T))) * torch.randn_like(samples)
samples_lang_noisedtraining =reverse_sde(scorenet, samples_lang_noisedtraining.to(dtype=torch.float32),torch.tensor(T)).detach().numpy()

# Deterministically evolving the normal distribution 
samples_lang_deterministic = torch.randn(10000,2)
samples_lang_deterministic = reverse_ode_flow(scorenet,samples_lang_deterministic,torch.tensor(T)).detach().numpy()

# %%
plt.clf()
p_samples = toy_data.inf_train_gen(dataset, batch_size = 10000)
samples_true = torch.tensor(p_samples).to(dtype = torch.float32)
plt.scatter(samples_true[:,0],samples_true[:,1],s = 0.1)
plt.axis('square')
plt.title('True samples')
plt.show()


plt.clf()
plt.scatter(samples_lang[:,0],samples_lang[:,1],s = 0.1)
plt.axis('square')
plt.title('Denoising normal distribution')
plt.show()


plt.clf()
plt.scatter(samples_lang_noisedtraining[:,0],samples_lang_noisedtraining[:,1],s = 0.1)
plt.axis('square')
plt.title('Denoising noised training samples')
plt.show()


plt.clf()
plt.scatter(samples_lang_deterministic[:,0],samples_lang_deterministic[:,1],s = 0.1)
plt.axis('square')
plt.title('Denoising normal with ODE flow')
plt.show()
